# %%
import os
import re
from hydraseq import Hydraseq

# %% [markdown]
# ## basic string breaker "word word2" -> ['word', 'word2']

# %%
def load_category_from_file(fpath):
    """Take a one word per line file and return a regex for the concatenation '^(w1|w2)$'"""
    with open(fpath, 'r') as source:
        ways = [line.strip().lower() for line in source]
    return r'^(' + "|".join(ways) + r')$'

def w(str_sentence):
    return re.findall(r"[\w'/-:]+|[.,!?;#&]", str_sentence)

# %%
seq = Hydraseq('input')

# %% [markdown]
# ## Encoder, takes a single word and returns a list of 'features' characterizing word

# %%
ways = load_category_from_file('ways.csv')
apts = load_category_from_file('apts.csv')
nths = load_category_from_file('nth.csv')
dirs = load_category_from_file('dirs.csv')
arti = load_category_from_file('arti.csv')
pre  = load_category_from_file('pre.csv')
deleg = load_category_from_file('deleg.csv')
print(apts)
def encoder(word, trim=False):
    encodings = [
        ('POBOX', [r'^:box$']),
        ('LETTER', [r'^[a-z]$']),
        ('ALNUM', [r'^(\d+[a-z]+|[a-z]+\d+)[\da-z]*$']),
        ('AL_1NUM', [ r'^\d+[a-z]$' ]),
        ('NTH',    [ nths ]),
        ('ATTN', [r'^:deleg$']),
        ('WAY',  [ ways ]),
        ('DIR',  [ dirs ]),
        ('NUMSTR', [r'^\d+[a-z]+$' ]),
        ('APT', [ apts ]),
        ('DIGIT', [r'^\d+$']),
        ('COMMA', [r'^,$']),
        ('PERIOD', [r'^\.$']),
        ('POUND', [r'^#$']),
        ('DELEG', [r'^attn$', r'^attn:$', r'^c\/o$', r'^co$' ]),
        ('POB0', [r'^po$', r'^p\.o\.$']),
        ('POB2', [r'^box$']),
        ('PRE',  [ pre ]),
        ('ARTI', [ arti ]),
        ('ADDRESS', [r'^:adr$']),
        ('ALPHA', [r'^[a-z]+$']),
    ]
    if not trim:
        return [key for key, rexs in encodings for rex in rexs if re.match(rex, word)]
    else:
        encoding = [key for key, rexs in encodings for rex in rexs if re.match(rex, word)]
        if len(encoding) > 1 and 'ALPHA' in encoding:
            encoding.remove('ALPHA')
        if len(encoding) > 1 and 'ALNUM' in encoding:
            encoding.remove('ALNUM')
        return encoding
            
        


def encode_sentence(st):
    return [encoder(word.lower()) for word in w(st)]

def encode_nested_list(st):
    return [[' '.join(encoder(word))] for word in w(st)]

def encode_from_word_list(arr_st):
    """Expects ['123', 'main', 'st]"""
    assert isinstance(arr_st, list)
    if arr_st: assert isinstance(arr_st[0], str)
    return [encoder(word) for word in arr_st]

def train(seq, sts):
    return seq.insert(encode_nested_list(sts)).get_next_values()

def train_with_provided_list(seq, matrix_lst):
    """matrix list means [['DIGIT'],['ALPHA'],['WAY']] for example"""
    return seq.insert(matrix_lst, is_learning=True).get_next_values()

def train_arr(seq, arr_w):
    return seq.insert([[' '.join(encoder(word))] for word in arr_w]).get_next_values()

def think(seq, sts):
    return seq.insert(encode_nested_list(sts), is_learning=False).get_next_values()

st = "100 n main st"
print(train(seq, st))
print(train_arr(seq, ["1217", "iris", "ct"]))
print(train_with_provided_list(seq, [['DIGIT'],['ALPHA']]))
print(train_with_provided_list(seq, [['DIGIT'], ['ALPHA'], ['WAY'], ['ADDRESS']]))
print(encode_from_word_list(['123','st','james','st']))
# Out:
# ^(apartment|apt|suite|ste|unit|lot|trlr|ro|spc|rm|fl|lbby|pmb|spc|)$
# []
# []
# ['WAY ALPHA']
# []
# [['DIGIT'], ['WAY', 'PRE', 'ALPHA'], ['ALPHA'], ['WAY', 'PRE', 'ALPHA']]

# %%
# THOU SHALL NOT SEQUENCE THREE ALPHAS IN A ROW!
tuples_training = [
("123 main st",                    [['DIGIT'], ['ALPHA'], ['WAY']]),
("1217 iris ct",                   [['DIGIT'], ['ALPHA'], ['WAY']]),
("123 east main st",               [['DIGIT'], ['DIR'], ['ALPHA'], ['WAY']]),
("310 W MAIN ST",                  [['DIGIT'], ['DIR'], ['ALPHA'], ['WAY']]),
("123 south main street.",         [['DIGIT'], ['DIR'], ['ALPHA'], ['WAY'], ['PERIOD']]),
("90 south park rd",               [['DIGIT'], ['DIR'], ['ALPHA'], ['WAY']]),
("987 el canyon ave",              [['DIGIT'], ['ARTI'], ['ALPHA'], ['WAY']]),
("333 st james st",                [['DIGIT'], ['PRE'], ['ALPHA'], ['WAY']]),
("123 west hill",                  [['DIGIT'], ['DIR'], ['ALPHA']]),
("77 el camino real",              [['DIGIT'], ['ARTI'], ['ALPHA'], ['ALPHA']]),
("1 bay st # b",                   [['DIGIT'], ['ALPHA'], ['WAY'], ['POUND'], ['LETTER']]),
("1 bay rd # b",                   [['DIGIT'], ['ALPHA'], ['WAY'], ['POUND'], ['LETTER']]),
("43 HUDSON AVE # 2",              [['DIGIT'], ['ALPHA'], ['WAY'], ['POUND'], ['DIGIT']]),
("111 san vicente blvd",           [['DIGIT'], ['PRE'], ['ALPHA'], ['WAY']]),
("28 black watch way",             [['DIGIT'], ['ALPHA'], ['ALPHA'], ['WAY']]),
("249 route 206",                  [['DIGIT'], ['WAY'], ['DIGIT']]),
("5500 lost tree",                 [['DIGIT'], ['ALPHA'], ['ALPHA']]),
("996 san benito st",              [['DIGIT'], ['PRE'], ['ALPHA'], ['WAY']]),
("899 embarcadero",                [['DIGIT'], ['ALPHA']]),
("177 montague e",                 [['DIGIT'], ['ALPHA'], ['DIR']]),
("2001 W COURT ST",                [['DIGIT'], ['DIR'], ['ALPHA'], ['WAY']]),
("12545 S HIGHWAY J",              [['DIGIT'], ['DIR'], ['WAY'], ['LETTER']]),
("437 S HIGHWAY 101 STE 501",      [['DIGIT'], ['DIR'], ['WAY'], ['DIGIT'], ['APT'], ['DIGIT']]),
("12940 S HIGHWAY 259",            [['DIGIT'], ['DIR'], ['WAY'], ['DIGIT']]),
("775 E 14 MILE RD",               [['DIGIT'], ['DIR'], ['DIGIT'], ['ALPHA'], ['WAY']]),
("4701 VAN DAM ST",                [['DIGIT'], ['ALPHA'], ['ALPHA'], ['WAY']]),
("3201 NEW MEXICO AVE NW STE 246", [['DIGIT'], ['ALPHA'], ['ALPHA'], ['WAY'], ['DIR'], ['APT'], ['DIGIT']]),
("111 RIO RANCHO BLVD SE",         [['DIGIT'], ['ALPHA'], ['ALPHA'], ['WAY'], ['DIR']]),
("17259 WILD HORSE CREEK RD",      [['DIGIT'], ['ALPHA'], ['ALPHA'], ['ALPHA'], ['WAY']]),
("12587 FAIR LAKES CIR STE 141",   [['DIGIT'], ['ALPHA'], ['ALPHA'], ['WAY'], ['APT'], ['DIGIT']]),
("107 E MARIPOSA DR",              [['DIGIT'], ['DIR'], ['ALPHA'], ['WAY']]),
("401 W FORT WILLIAMS ST",         [['DIGIT'], ['DIR'], ['ALPHA'], ['ALPHA'], ['WAY']]),
("3242 E DESERT INN RD STE 17",    [['DIGIT'], ['DIR'], ['ALPHA'], ['ALPHA'], ['WAY'], ['APT'], ['DIGIT']]),
("14238 44ND AVE",                 [['DIGIT'], ['NUMSTR'], ['WAY']]),
("106 HARVEST HILL LN",            [['DIGIT'], ['ALPHA'], ['ALPHA'], ['WAY']]),
("206 ELMHURST DR APT F15",        [['DIGIT'], ['ALPHA'], ['WAY'], ['APT'], ['ALNUM']]),
("655 COUNTY ROAD 1300",           [['DIGIT'], ['ALPHA'], ['WAY'], ['DIGIT']]),
("50 LOS PATOS WAY",               [['DIGIT'], ['ARTI'], ['ALPHA'], ['WAY']]),
("1001 N 60TH ST",                 [['DIGIT'], ['DIR'], ['NUMSTR'], ['WAY']]),
("5350 S SANTA FE DR",             [['DIGIT'], ['DIR'], ['ALPHA'], ['ALPHA'], ['WAY']]),
("638 18TH ST",                    [['DIGIT'], ['NUMSTR'], ['WAY']]),
("210 E 3RD AVE",                  [['DIGIT'], ['DIR'], ['NUMSTR'], ['WAY']]),
("1390 SW 160TH AVE",              [['DIGIT'], ['DIR'], ['NUMSTR'], ['WAY']]),
("171 NE 212TH ST",                [['DIGIT'], ['DIR'], ['NUMSTR'], ['WAY']]),
("712 B MAIN ST",                  [['DIGIT'], ['LETTER'], ['ALPHA'], ['WAY']]),
("2060 B MOUNTAIN BLVD",           [['DIGIT'], ['LETTER'], ['ALPHA'], ['WAY']]),
("123 avenue c",                   [['DIGIT'], ['WAY'], ['LETTER']]),
("717B GRAVES ST",                 [['ALNUM'], ['ALPHA'], ['WAY']]),
("1234 7TH AVENUE",                [['DIGIT'], ['NTH'], ['WAY']]),
("205 3RD AVE APT 3K",             [['DIGIT'], ['NTH'], ['WAY'], ['APT'], ['ALNUM']]),
("462 7TH AVE FL 2",               [['DIGIT'], ['NTH'], ['WAY'], ['ALPHA'], ['DIGIT']]),
    ("219 2ND AVE SE STE 101",     [['DIGIT'], ['NTH'], ['WAY'], ['DIR'], ['APT'], ['DIGIT']]),
    ("10859 12TH AVE SW",          [['DIGIT'], ['NTH'], ['WAY'], ['DIR']]),
    ("4401 LOOP 322",              [['DIGIT'], ['ALPHA'], ['DIGIT']]),
    ("8690 EDGE OF TEXAS",         [['DIGIT'], ['ALPHA'], ['ARTI'], ['ALPHA']]),
    ("487 RITCHIE HWY B102",       [['DIGIT'], ['ALPHA'], ['WAY'], ['ALNUM']]),
    ("366 RAILROAD AVE LOT 31", [['DIGIT'], ['ALPHA'], ['WAY'], ['APT'], ['DIGIT']]),
    ("1631A S MAIN ST",         [['AL_1NUM'],['DIR'],['ALPHA'],['WAY']]),
    ("338A 7TH AVE", [['AL_1NUM'],['NTH'],['WAY']]),
    #("3RD ST", [['NTH'],['WAY']]), THIS IS IN INCOPLETE ADDRESS
    ("1771A PRINCESS ANNE RD", [['AL_1NUM'], ['ALPHA'], ['ALPHA'], ['WAY']]),
    ("751 ROUTE 37 W", [['DIGIT'], ['WAY'], ['DIGIT'], ['DIR']]),
    ("73140 HIGHWAY 111 STE 6", [['DIGIT'], ['WAY'], ['DIGIT'], ['APT'], ['DIGIT']]),
    ("476534 HIGHWAY 95 STE A", [['DIGIT'], ['WAY'], ['DIGIT'], ['APT'], ['LETTER']]),
    ("225 LA PALOMA APT A", [['DIGIT'], ['ARTI'], ['ALPHA'], ['APT'], ['LETTER']]), # DIFF!
    ("3200 SISK RD STE C", [['DIGIT'], ['ALPHA'], ['WAY'], ['APT'], ['LETTER']]), # DIFF!
    ("2584 US HIGHWAY 80 W", [['DIGIT'], ['ALPHA'], ['WAY'], ['DIGIT'], ['DIR']]), # DIFF!
    ("2387 PORTOLA RD STE A", [['DIGIT'], ['ALPHA'], ['WAY'], ['APT'], ['LETTER']]), # DIFF!
    ("118 N 300 W", [['DIGIT'], ['DIR'], ['DIGIT'], ['DIR']]),
    ("1027 S WESTERN AVE # 2", [['DIGIT'], ['DIR'], ['ALPHA'], ['WAY'], ['POUND'], ['DIGIT']]),
    ("690 S STATE HIGHWAY 5", [['DIGIT'], ['DIR'], ['ALPHA'], ['WAY'], ['DIGIT']]),
    ("3070 W CHAPMAN AVE STE A", [['DIGIT'], ['DIR'], ['ALPHA'], ['WAY'], ['APT'], ['LETTER']]),
    ("1420 E PLAZA BLVD STE D5", [['DIGIT'], ['DIR'], ['ALPHA'], ['WAY'], ['APT'], ['ALNUM']]),
    ("82 S MAIN ST # 2", [['DIGIT'], ['DIR'], ['ALPHA'], ['WAY', 'PRE'], ['POUND'], ['DIGIT']]),
    ("473 S MAIN ST STE A", [['DIGIT'], ['DIR'], ['ALPHA'], ['WAY'], ['APT'], ['LETTER']]),
    ("1029 W BATTLEFIELD ST APT E214", [['DIGIT'], ['DIR'], ['ALPHA'], ['WAY', 'PRE'], ['APT'],['ALNUM']]),
    ("3843 S BRISTOL 213", [['DIGIT'], ['DIR'], ['ALPHA'], ['DIGIT']]),
    ("", [['DIGIT'], ['DIR'], ['PERIOD'], ['ALPHA'], ['WAY']]),
    ("", [['DIGIT'], ['LETTER', 'DIR'], ['PERIOD'], ['ALPHA'], ['WAY']]),
    ("", [['DIGIT'], ['ALPHA'], ['WAY'], ['DIR']]),
    ("", [['DIGIT'], ['ALPHA'], ['WAY', 'PRE'], ['PERIOD']]),
]
for ts, matrix_lst in tuples_training:
    matrix_lst.append(['ADDRESS'])
    train_with_provided_list(seq, matrix_lst)

# valid po box
train_samples = [
    ("po box 1234", [['POB0'],['POB2'],['DIGIT']]),
    ("box 999",      [['POB2'],['DIGIT']]),
]
for ts, matrix_lst in train_samples:
    matrix_lst.append(['POBOX'])
    train_with_provided_list(seq, matrix_lst)

# valid attn
train_samples = [
    ("c/o john smith",     [['DELEG'],['ALPHA'],['ALPHA']]),
    ("attn john smith",    [['DELEG'],['ALPHA'],['ALPHA']]),
    ("attn: john smith",   [['DELEG'],['ALPHA'],['ALPHA']]),
    ("c/o john",           [['DELEG'],['ALPHA']]),
]
for ts, matrix_lst in train_samples:
    matrix_lst.append(['ATTN'])
    train_with_provided_list(seq, matrix_lst)

# %% [markdown]
# ## The lexicon and get_normalized fn determine how to intepret a word.
# * So for example, 'st', can mean 'saint', or 'street', depending if we look at it in the context of 'pre'(prefix) or 'way' as in a street or road designation.

# %% [markdown]
# ## Next steps...
# * Combine encoded sentence with a predetermined pattern, say like expecting 'way' type of words at end and see if we can reliably interpret the meaning of abbrevs like st.
# * Automate geneation of the address templates by running encoder on a looooong list of valid addresses
# * Hopefully after that an address can be normalized reliably... and this can then be applied maybe to business names....
#
# * and IF that works, ^^, then do it for 'c/o', 'attn:', and 'po box' phrases... and the write more code to break up a long sentence into its composite phrases.  So like "some very long string with lots of words" => "c/o substring" + "valid address" + "junk on end".....

# %%
def is_address(seq, arr_st):
        """Expects ["123","main","st"]"""
        return any([pred == 'ADDRESS' for pred in seq.look_ahead(encode_from_word_list(arr_st)).get_next_values()])

def is_pobox(seq, arr_st):
    """Expects ["123","main","st"]"""
    assert isinstance(arr_st, list)
    return any([pred == 'POBOX' for pred in seq.look_ahead(encode_from_word_list(arr_st)).get_next_values()])

sent = "po box 7001"
assert is_pobox(seq, w(sent)) == True

def is_deleg(seq, arr_st):
    """Expects ["123","main","st"]"""
    assert isinstance(arr_st, list)
    return any([pred == 'ATTN' for pred in seq.look_ahead(encode_from_word_list(arr_st)).get_next_values()])

sent = "attn john doe"
assert is_deleg(seq, w(sent)) == True

# %%
def get_markers(seq, sent, lst_targets):
    """Input is like '123 main str' and returns a list of lists"""
    arr_w = w(sent)
    idx_tail = len(arr_w)
    markers = []
    for idx_beg in range(idx_tail):
        for idx_end in range(idx_beg + 1, idx_tail +1):
            next_values = seq.look_ahead(encode_from_word_list(arr_w[idx_beg:idx_end])).get_next_values()
            matches = list(set(next_values) & set(lst_targets) )
            if matches:
                markers.append([idx_beg, idx_end, idx_end - idx_beg, matches, ' '.join(arr_w[idx_beg:idx_end])])
    return markers


#st = "c/o john smith 100 maple ave"
st = "317 N WOODWORK LANE LLC 317 WOODWORK LANE"
get_markers(seq, st.lower(), ['ADDRESS'])
# Out:
# [[0, 2, 2, ['ADDRESS'], '317 n'],
#  [0, 3, 3, ['ADDRESS'], '317 n woodwork'],
#  [0, 4, 4, ['ADDRESS'], '317 n woodwork lane'],
#  [5, 7, 2, ['ADDRESS'], '317 woodwork'],
#  [5, 8, 3, ['ADDRESS'], '317 woodwork lane']]

# %%
def get_markers2(seq, sent, lst_targets):
    """Input is like '123 main str' and returns a list of lists"""
    arr_w = w(sent)
    idx_tail = len(arr_w)
    markers = []
    for idx_beg in range(idx_tail):
        for idx_end in range(idx_beg + 1, idx_tail +1):
            next_values = seq.look_ahead(encode_from_word_list(arr_w[idx_beg:idx_end])).get_next_values()
            matches = list(set(next_values) & set(lst_targets) )
            if matches:
                markers.append([idx_beg, idx_end, idx_end - idx_beg, matches, ' '.join(arr_w[idx_beg:idx_end])])
    return markers


#st = "c/o john smith 100 maple ave"
st = "4 STAR CAMPS 2171 IVY RD STE 3"
get_markers(seq, st.lower(), ['ADDRESS', 'ATTN', 'POBOX'])
# Out:
# [[0, 2, 2, ['ADDRESS'], '4 star'],
#  [0, 3, 3, ['ADDRESS'], '4 star camps'],
#  [3, 5, 2, ['ADDRESS'], '2171 ivy'],
#  [3, 6, 3, ['ADDRESS'], '2171 ivy rd'],
#  [3, 8, 5, ['ADDRESS'], '2171 ivy rd ste 3']]

# %%
def return_max_address(seq, sent):
    sent = str(sent).lower().strip()
    arr_cands = get_markers(seq, sent, ['ADDRESS'])
    if not arr_cands:
        return str([encoder(word) for word in w(sent)])
    
    max_len = 0
    for cand in arr_cands:
        if cand[2] > max_len:
            max_len = cand[2]
            candidate_address = cand[4]
    
    candidate_address = candidate_address.upper()
    if candidate_address != sent.upper():
        return '("", {}),'.format(str([encoder(word, trim=True) for word in w(sent)]))
    else:
        return candidate_address

return_max_address(seq, "16w661 90th st")
# Out:
# "[['ALNUM'], ['ALNUM', 'NTH', 'NUMSTR'], ['WAY', 'PRE', 'ALPHA']]"

# %%
field1 = "280 NW 123RD LN"
field2 = "288 NE 53RD ST"
print(return_max_address(seq, field2))
# Out:
# 288 NE 53RD ST

# %%
import pandas as pd

# %%
df = pd.read_csv('fivehundred_more_addresses_no_spaces_sorted.csv')

# %%
df_addresses = df[['address1']]
df_addresses.drop_duplicates(keep='first', inplace=True)
# Out:
# /Users/niarfe/tmprepos/sandbox/env/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# %%time
df_addresses['NEW ADDRESS'] = df_addresses['address1'].apply(lambda x: return_max_address(seq, x))
# Out:
# CPU times: user 918 ms, sys: 7.17 ms, total: 925 ms
# Wall time: 930 ms
# /Users/niarfe/tmprepos/sandbox/env/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_addresses.head()
# Out:
#                                    address1  \
# 0  & DECOR CENTER LLC 750 SOUTH 13TH STREET
# 1                       0-794 CHICAGO DRIVE
# 2                         1 BRUSSELS STREET
# 3                            1 EAGLE SQUARE
# 4                              1 JFK STREET
#
#                                          NEW ADDRESS
# 0  ("", [[], ['ALPHA'], ['ALPHA'], ['ALPHA'], ['D...
# 1  ("", [['DIGIT'], ['DIGIT'], ['ALPHA'], ['WAY']]),
# 2                                  1 BRUSSELS STREET
# 3                                     1 EAGLE SQUARE
# 4                                       1 JFK STREET

# %%
df_addresses.to_csv('processed_addresses.csv')
! open 'processed_addresses.csv'

# %%
from collections import Counter
wcount = Counter()

def count_words(ctr, st):
    arr_words = w(st)
    for idx, word in enumerate(arr_words):
        if not word.isdigit():
            ctr[word] += 1
            bigram = arr_words[idx:idx+2]
            #print(arr_words[idx:idx+2])
            if len(bigram) == 2:
                ctr["-".join(bigram)] += 1
    return st

df_addresses['address1'].apply(lambda x: count_words(wcount, x))
wcount.most_common()
# Out:
# [('STREET', 113),
#  ('ST', 101),
#  ('AVE', 95),
#  ('RD', 87),
#  ('.', 83),
#  ('STE', 75),
#  ('ROAD', 74),
#  ('AVENUE', 49),
#  ('S', 46),
#  ('DR', 42),
#  ('DRIVE', 40),
#  ('E', 40),
#  ('SUITE', 39),
#  (',', 36),
#  ('W', 32),
#  ('BLVD', 31),
#  ('N', 31),
#  ('#', 31),
#  ('MAIN', 29),
#  ('WEST', 22),
#  ('EAST', 19),
#  ('ST-.', 18),
#  ('UNIT', 17),
#  ('MAIN-ST', 16),
#  ('LANE', 16),
#  ('HWY', 14),
#  ('SOUTH', 13),
#  ('A', 13),
#  ('AVE-.', 13),
#  ('NORTH', 12),
#  ('MAIN-STREET', 12),
#  (',-SUITE', 12),
#  ('B', 11),
#  ('WAY', 11),
#  ('LLC', 10),
#  (',-STE', 9),
#  ('COURT', 9),
#  ('NE', 9),
#  ('S-.', 9),
#  ('CENTER', 8),
#  ('NW', 8),
#  ('PARK', 8),
#  ('ROUTE', 8),
#  ('E-.', 8),
#  ('OLD', 7),
#  ('W-.', 7),
#  ('ST-STE', 7),
#  ('CIRCLE', 7),
#  ('STREET-STE', 7),
#  ('BROADWAY', 7),
#  ('STATE', 7),
#  ('CT', 7),
#  ('HILL', 7),
#  ('RIDGE', 7),
#  ('WATER', 6),
#  ('.-MAIN', 6),
#  ('INDUSTRIAL', 6),
#  ('RD-STE', 6),
#  ('RIVER', 6),
#  ('OAK', 6),
#  ('APT', 6),
#  ('BRIDGE', 6),
#  ('PLAZA', 5),
#  ('SE', 5),
#  ('STREET-SUITE', 5),
#  ('N-.', 5),
#  (',-UNIT', 5),
#  ('BOX', 5),
#  ('RD-.', 5),
#  ('ROAD-STE', 5),
#  ('BLVD-STE', 5),
#  ('DR-STE', 5),
#  ('.-,', 5),
#  ('DR-.', 5),
#  ('SQUARE', 4),
#  ('.-STE', 4),
#  ('ST-,', 4),
#  ('COUNTRY', 4),
#  ('US', 4),
#  ('PARK-DRIVE', 4),
#  ('STE-210', 4),
#  ('.-#', 4),
#  ('SPRING', 4),
#  ('D', 4),
#  ('LN', 4),
#  ('LAKE', 4),
#  ('H', 4),
#  ('STE-200', 4),
#  ('FLOOR', 4),
#  ('MAPLE', 4),
#  ('SW', 4),
#  ('WASHINGTON', 4),
#  ('PIKE', 4),
#  ('PKWY', 4),
#  ('STE-.', 4),
#  ('STATE-ST', 4),
#  ('CENTRAL', 4),
#  ('CHICAGO', 3),
#  ('ASHLAND', 3),
#  ('SOUTH-MAIN', 3),
#  ('AVE-STE', 3),
#  ('14TH', 3),
#  ('FL', 3),
#  ('THE', 3),
#  ('PO', 3),
#  ('PO-BOX', 3),
#  ('PARKWAY', 3),
#  ('CREEK', 3),
#  ('RD-SUITE', 3),
#  ('DRIVE-STE', 3),
#  ('STREET-#', 3),
#  ('CYPRESS', 3),
#  ('PACIFIC', 3),
#  ('MOUNTAIN', 3),
#  ('STE-B', 3),
#  ('VALLEY', 3),
#  ('WATER-STREET', 3),
#  ('SHERMAN', 3),
#  ('SOUTHWEST', 3),
#  ('COMMERCE', 3),
#  ('FOREST', 3),
#  ('HILL-ROAD', 3),
#  ('AVE-,', 3),
#  ('GREEN', 3),
#  ('UNIT-A', 3),
#  ('GOLF', 3),
#  ('WORCESTER', 3),
#  ('INDUSTRIAL-PARK', 3),
#  ('VILLAGE', 3),
#  ('ST-SUITE', 3),
#  ('COLORADO', 3),
#  ('AVENUE-STE', 3),
#  ('RIVER-ROAD', 3),
#  ('G', 3),
#  ('BOULEVARD', 3),
#  ('PEACHTREE', 3),
#  ('HIGHWAY', 3),
#  ('38TH', 3),
#  ('AVE-#', 3),
#  ('VIA', 3),
#  ('POND', 3),
#  ('POND-ROAD', 3),
#  ('RD-#', 3),
#  ('GRAND', 3),
#  ('CHAPEL', 3),
#  ('STE-102', 3),
#  ('CLARK', 3),
#  ('PLACE', 3),
#  ('BROAD', 3),
#  ('BROAD-STREET', 3),
#  ('3RD', 3),
#  ('3RD-STREET', 3),
#  ('CENTRAL-AVE', 3),
#  ('&', 2),
#  ('13TH', 2),
#  ('PL', 2),
#  ('SUNSET', 2),
#  ('THOMPSON', 2),
#  ('45TH', 2),
#  ('AVE-SUITE', 2),
#  ('SUITE-150', 2),
#  ('CHESTERTON', 2),
#  ('WESTERN', 2),
#  ('ISLAND', 2),
#  ('FM', 2),
#  ('SPRINGFIELD', 2),
#  ('MEADOW', 2),
#  ('UNIT-B', 2),
#  ('COVE', 2),
#  ('11TH', 2),
#  ('MYRTLE', 2),
#  ('23RD', 2),
#  ('#-500', 2),
#  ('RD-UNIT', 2),
#  ('LINCOLN', 2),
#  ('FRWY', 2),
#  ('PACIFIC-COAST', 2),
#  ('COAST', 2),
#  ('COAST-HWY', 2),
#  ('DRIVE-WEST', 2),
#  ('LINDEN', 2),
#  ('1ST', 2),
#  ('VALLEY-BLVD', 2),
#  ('STE-100', 2),
#  ('H-STREET', 2),
#  ('BLVD-#', 2),
#  ('#-5', 2),
#  ('N-MAIN', 2),
#  ('AVE-S', 2),
#  ('SPRING-STREET', 2),
#  ('BLVD-.', 2),
#  ('MILE', 2),
#  ('MILE-RD', 2),
#  ('FULTON', 2),
#  ('F', 2),
#  ('4TH', 2),
#  ('AVE-SOUTH', 2),
#  ('LOS', 2),
#  ('#-A', 2),
#  ('STE-1200', 2),
#  ('37TH', 2),
#  ('6TH', 2),
#  ('RAVINIA', 2),
#  ('47TH', 2),
#  ('ST-UNIT', 2),
#  ('ALAMEDA', 2),
#  ('COUNTRY-CLUB', 2),
#  ('CLUB', 2),
#  ('SOUTHBRIDGE', 2),
#  ('GOLF-ROAD', 2),
#  ('HARLEM', 2),
#  ('UPPER', 2),
#  ('WALTON', 2),
#  ('WOODLAND', 2),
#  ('WARREN', 2),
#  ('HILL-RD', 2),
#  ('EAST-INDUSTRIAL', 2),
#  ('MASSACHUSETTS', 2),
#  ('MASSACHUSETTS-AVE', 2),
#  ('.-SUITE', 2),
#  ('CENTER-CIRCLE', 2),
#  ('PINE', 2),
#  ('VILLAGE-SQUARE', 2),
#  ('8TH', 2),
#  ('FIRST', 2),
#  ('HAYES', 2),
#  ('S-MAIN', 2),
#  ('ENGLISH', 2),
#  ('NORTH-MAIN', 2),
#  ('PKWY-SUITE', 2),
#  ('MILLER', 2),
#  ('MILLER-DRIVE', 2),
#  ('DRIVE-SUITE', 2),
#  ('SUITE-G', 2),
#  ('JOHN', 2),
#  ('WAY-STE', 2),
#  ('ST-APT', 2),
#  ('COMMERCIAL', 2),
#  ('LANE-,', 2),
#  ('R', 2),
#  ('VICTORY', 2),
#  ('VICTORY-BLVD', 2),
#  ('HONOLULU', 2),
#  ('HONOLULU-AVE', 2),
#  ('#-1', 2),
#  ('BROOK', 2),
#  ('HOLLOW', 2),
#  ('36TH', 2),
#  ('TANGLEWILDE', 2),
#  ('TANGLEWILDE-,', 2),
#  ('HENRY', 2),
#  ('SUITE-100', 2),
#  ('VAN', 2),
#  ('SUMMIT', 2),
#  ('20TH', 2),
#  ('20TH-STREET', 2),
#  ('STE-201', 2),
#  ('WATERMAN', 2),
#  ('N-WINOOSKI', 2),
#  ('WINOOSKI', 2),
#  ('B-ST', 2),
#  ('E-STATE', 2),
#  ('CHAPEL-RD', 2),
#  ('GRAND-AVE', 2),
#  ('EAST-MAIN', 2),
#  ('LAKE-RD', 2),
#  ('WOODWORK', 2),
#  ('WOODWORK-LANE', 2),
#  ('CAMINO', 2),
#  ('ROYAL', 2),
#  ('BEDFORD', 2),
#  ('SUITE-200', 2),
#  ('CHESTNUT', 2),
#  ('CLARK-ROAD', 2),
#  ('CAMPUS', 2),
#  ('CAMPUS-DRIVE', 2),
#  ('STE-3', 2),
#  ('SMITH', 2),
#  ('WASHINGTON-STREET', 2),
#  ('PERKINS', 2),
#  ('STE-400', 2),
#  ('ROAD-,', 2),
#  ('SUITE-300', 2),
#  ('STREET-,', 2),
#  ('WING', 2),
#  ('C', 2),
#  ('PEACHTREE-ROAD', 2),
#  ('ROAD-SUITE', 2),
#  ('EUCLID', 2),
#  ('S-CENTRAL', 2),
#  ('DR-#', 2),
#  ('MARKET', 2),
#  ('BRIDGE-RD', 2),
#  ('GROVE', 2),
#  ('3A', 2),
#  ('RIDGE-RD', 2),
#  ('HARBOR', 2),
#  ('CENTER-INC', 2),
#  ('INC', 2),
#  ('&-DECOR', 1),
#  ('DECOR', 1),
#  ('DECOR-CENTER', 1),
#  ('CENTER-LLC', 1),
#  ('LLC-750', 1),
#  ('SOUTH-13TH', 1),
#  ('13TH-STREET', 1),
#  ('CHICAGO-DRIVE', 1),
#  ('BRUSSELS', 1),
#  ('BRUSSELS-STREET', 1),
#  ('EAGLE', 1),
#  ('EAGLE-SQUARE', 1),
#  ('JFK', 1),
#  ('JFK-STREET', 1),
#  ('ODELL', 1),
#  ('ODELL-PLAZA', 1),
#  ('RENAISSANCE', 1),
#  ('RENAISSANCE-PL', 1),
#  ('PL-UNIT', 1),
#  ('UNIT-911', 1),
#  ('SUNSET-DRIVE', 1),
#  ('DRIVE-NORTH', 1),
#  ('ASHLAND-ST', 1),
#  ('CHARLOTTE', 1),
#  ('CHARLOTTE-STREET', 1),
#  ('S-GLOCHESKI', 1),
#  ('GLOCHESKI', 1),
#  ('SUNSET-THOMPSON', 1),
#  ('LINWOOD', 1),
#  ('LINWOOD-STREET', 1),
#  ('SE-WATER', 1),
#  ('WATER-AVE', 1),
#  ('STE-350', 1),
#  ('HART', 1),
#  ('HART-AVE', 1),
#  ('FEDERAL', 1),
#  ('FEDERAL-ST', 1),
#  ('STE-1400', 1),
#  (',-14TH', 1),
#  ('14TH-FL', 1),
#  ('45TH-AVENUE', 1),
#  ('SANDHILL', 1),
#  ('SANDHILL-AVE', 1),
#  ('W-WINDSOR', 1),
#  ('WINDSOR', 1),
#  ('WINDSOR-BLVD', 1),
#  ('W-UNIVERITY', 1),
#  ('UNIVERITY', 1),
#  ('UNIVERITY-AVE', 1),
#  ('CHESTERTON-DRIVE', 1),
#  ('N-WESTERN', 1),
#  ('WESTERN-ISLAND', 1),
#  ('S-CLAREMONT', 1),
#  ('CLAREMONT', 1),
#  ('CLAREMONT-STREET', 1),
#  ('COUNTRY-HORN', 1),
#  ('HORN', 1),
#  ('OLD-PLACERVILLE', 1),
#  ('PLACERVILLE', 1),
#  ('PLACERVILLE-RD', 1),
#  ('E-FREDRICKS', 1),
#  ('FREDRICKS', 1),
#  ('FREDRICKS-ST', 1),
#  ('TULUNE', 1),
#  ('TULUNE-AVENUE', 1),
#  ('.-HIGGINS', 1),
#  ('HIGGINS', 1),
#  ('HIGGINS-ROAD', 1),
#  ('FM-1960', 1),
#  ('E-SPRINGFIELD', 1),
#  ('SPRINGFIELD-RD', 1),
#  ('EAST-MONTAGIE', 1),
#  ('MONTAGIE', 1),
#  ('MONTAGIE-AVENUE', 1),
#  ('AVENUE-NORTH', 1),
#  ('AVENUE-OF', 1),
#  ('OF', 1),
#  ('OF-THE', 1),
#  ('THE-AMERICAS', 1),
#  ('AMERICAS', 1),
#  ('ROCKY', 1),
#  ('ROCKY-MEADOW', 1),
#  ('MEADOW-STREET', 1),
#  ('SKILLMAN', 1),
#  ('SKILLMAN-STREET', 1),
#  ('SUITE-7B', 1),
#  ('7B', 1),
#  ('FLORIDA', 1),
#  ('FLORIDA-AVE', 1),
#  ('.-BATAVIA', 1),
#  ('BATAVIA', 1),
#  ('BATAVIA-ST', 1),
#  ('LYELL', 1),
#  ('LYELL-AVE', 1),
#  ('E-TRAVERSE', 1),
#  ('TRAVERSE', 1),
#  ('TRAVERSE-HWY', 1),
#  ('HWY-SUITE', 1),
#  ('SUITE-5595', 1),
#  ('SE-FULLER', 1),
#  ('FULLER', 1),
#  ('FULLER-ROAD', 1),
#  ('W-HWY', 1),
#  ('HWY-55', 1),
#  ('#-201', 1),
#  ('N-OLD', 1),
#  ('OLD-US', 1),
#  ('US-27', 1),
#  ('BOX-186', 1),
#  ('CHICAGO-DR', 1),
#  ('10A', 1),
#  ('10A-MANOR', 1),
#  ('MANOR', 1),
#  ('MANOR-PARKWAY', 1),
#  ('ROUNDABOUT', 1),
#  ('ROUNDABOUT-DRIVE', 1),
#  ('TECHNOLOGY', 1),
#  ('TECHNOLOGY-DR', 1),
#  ('AMBER', 1),
#  ('AMBER-CREEK', 1),
#  ('CREEK-DRIVE', 1),
#  ('KOALA', 1),
#  ('KOALA-COVE', 1),
#  ('N-CHICAGO', 1),
#  ('CHICAGO-AVE', 1),
#  ('VERMONT', 1),
#  ('VERMONT-AVENUE', 1),
#  ('AVENUE-NW', 1),
#  ('MELBOURNE', 1),
#  ('MELBOURNE-RD', 1),
#  ('SUITE-3037', 1),
#  ('N-RADDANT', 1),
#  ('RADDANT', 1),
#  ('RADDANT-ROAD', 1),
#  ('VANOWEN', 1),
#  ('VANOWEN-ST', 1),
#  ('W-ELDORADO', 1),
#  ('ELDORADO', 1),
#  ('ELDORADO-ST', 1),
#  ('CENTER-PARK', 1),
#  ('ORION', 1),
#  ('ORION-ST', 1),
#  ('EAST-BERKS', 1),
#  ('BERKS', 1),
#  ('BERKS-ST', 1),
#  ('S-11TH', 1),
#  ('11TH-STREET', 1),
#  ('HEMPHILL', 1),
#  ('HEMPHILL-AVE', 1),
#  ('#-227', 1),
#  ('18TH', 1),
#  ('18TH-ST', 1),
#  ('E-MAIN', 1),
#  ('MYRTLE-ST', 1),
#  ('HAMILTON', 1),
#  ('HAMILTON-NW', 1),
#  ('WEST-BOYLSTON', 1),
#  ('BOYLSTON', 1),
#  ('BOYLSTON-STREET', 1),
#  ('EAST-GRACE', 1),
#  ('GRACE', 1),
#  ('GRACE-STREET', 1),
#  ('ROUTE-22', 1),
#  ('WEST-23RD', 1),
#  ('23RD-STREET', 1),
#  ('STREET-.', 1),
#  ('N-RODNEY', 1),
#  ('RODNEY', 1),
#  ('RODNEY-PARHAM', 1),
#  ('PARHAM', 1),
#  ('PARHAM-RD', 1),
#  ('SPRING-CYPRESS', 1),
#  ('CYPRESS-RD', 1),
#  ('NORTH-LINCOLN', 1),
#  ('LINCOLN-ST', 1),
#  ('STE-105', 1),
#  ('WEST-PICO', 1),
#  ('PICO', 1),
#  ('PICO-BLVD', 1),
#  ('S-CROCKER', 1),
#  ('CROCKER', 1),
#  ('CROCKER-ST', 1),
#  ('KATY', 1),
#  ('KATY-FRWY', 1),
#  ('FRWY-#', 1),
#  ('#-410', 1),
#  ('.-HOSPITAL', 1),
#  ('HOSPITAL', 1),
#  ('HOSPITAL-,', 1),
#  ('STE-203', 1),
#  ('B-KIRKLAND', 1),
#  ('KIRKLAND', 1),
#  ('KIRKLAND-CIRCLE', 1),
#  ('GONTRUM', 1),
#  ('GONTRUM-ROAD', 1),
#  ('MILO', 1),
#  ('MILO-RD', 1),
#  ('EASY', 1),
#  ('EASY-GAP', 1),
#  ('GAP', 1),
#  ('GAP-ROAD', 1),
#  ('HOOKSETT', 1),
#  ('HOOKSETT-RD', 1),
#  ('ROYVONNE', 1),
#  ('ROYVONNE-AVE', 1),
#  ('AVE-SE', 1),
#  ('SE-#', 1),
#  ('#-22', 1),
#  ('HWY-D', 1),
#  ('D-331', 1),
#  ('INTERCHANGE', 1),
#  ('INTERCHANGE-DRIVE', 1),
#  ('PETRA', 1),
#  ('PETRA-LANE', 1),
#  ('POST', 1),
#  ('POST-OFFICE', 1),
#  ('OFFICE', 1),
#  ('OFFICE-SQUARE', 1),
#  ('SQUARE-,', 1),
#  (',-6F', 1),
#  ('6F', 1),
#  ('LINDEN-ST', 1),
#  ('MOUNTAIN-AVE', 1),
#  ('STANLEY', 1),
#  ('STANLEY-ST', 1),
#  ('ROUTE-22E', 1),
#  ('22E', 1),
#  ('W-SECOND', 1),
#  ('SECOND', 1),
#  ('SECOND-ST', 1),
#  ('INDIAN', 1),
#  ('INDIAN-CREEK', 1),
#  ('CREEK-COURT', 1),
#  ('COURT-STE', 1),
#  ('1ST-AVENUE', 1),
#  ('AVENUE-NE', 1),
#  ('KIRKHAM', 1),
#  ('KIRKHAM-ROAD', 1),
#  ('S-MOPAC', 1),
#  ('MOPAC', 1),
#  ('MOPAC-EXPY', 1),
#  ('EXPY', 1),
#  ('EXPY-STE', 1),
#  ('113TH', 1),
#  ('113TH-AVE', 1),
#  ('AVE-NE', 1),
#  ('NE-STE', 1),
#  ('VETERANS', 1),
#  ('VETERANS-BLVD', 1),
#  ('BANKER', 1),
#  ('BANKER-ST', 1),
#  ('BONNY', 1),
#  ('BONNY-LN', 1),
#  ('E-CARLTON', 1),
#  ('CARLTON', 1),
#  ('CARLTON-ST', 1),
#  ('ST-PO', 1),
#  ('BOX-651', 1),
#  ('GLENWOOD', 1),
#  ('GLENWOOD-DR', 1),
#  ('ST-9TH', 1),
#  ('9TH', 1),
#  ('9TH-FL', 1),
#  ('INWOOD', 1),
#  ('INWOOD-ROAD', 1),
#  ('STE-160', 1),
#  ('JAMES', 1),
#  ('JAMES-STREET', 1),
#  ('STE-B40', 1),
#  ('B40', 1),
#  ('CARRABASSETT', 1),
#  ('CARRABASSETT-DRIVE', 1),
#  ('DONS', 1),
#  ('DONS-WAY', 1),
#  ('LAKE-STREET', 1),
#  ('STREET-WEST', 1),
#  ('WEST-STE', 1),
#  ('STE-212', 1),
#  ('STREET-NW', 1),
#  ('NW-,', 1),
#  ('SUITE-1150', 1),
#  ('S-LYNNHAVEN', 1),
#  ('LYNNHAVEN', 1),
#  ('LYNNHAVEN-ROAD', 1),
#  ('FM-529', 1),
#  ('EAST-289', 1),
#  ('TH', 1),
#  ('TH-STREET', 1),
#  ('N-SAGUARO', 1),
#  ('SAGUARO', 1),
#  ('SAGUARO-BLVD', 1),
#  ('NE-MARX', 1),
#  ('MARX', 1),
#  ('MARX-STREET', 1),
#  ('CUSHNOC', 1),
#  ('CUSHNOC-RD', 1),
#  ('YOSEMITE', 1),
#  ('YOSEMITE-AVE', 1),
#  ('PRESTWICK', 1),
#  ('PRESTWICK-DR', 1),
#  ('LAKESIDE', 1),
#  ('LAKESIDE-DR', 1),
#  ('DR-UNIT', 1),
#  ('UNIT-6', 1),
#  ('SE-RIO', 1),
#  ('RIO', 1),
#  ('RIO-CASARANO', 1),
#  ('CASARANO', 1),
#  ('CASARANO-PORT', 1),
#  ('PORT', 1),
#  ('GLEN', 1),
#  ('GLEN-ERICA', 1),
#  ('ERICA', 1),
#  ('ERICA-DRIVE', 1),
#  ('BARNHILL', 1),
#  ('BARNHILL-LANE', 1),
#  ('12TH', 1),
#  ('12TH-ST', 1),
#  ('PROVIDENCE', 1),
#  ('PROVIDENCE-ROAD', 1),
#  ('CRENSHAW', 1),
#  ('CRENSHAW-BLVD', 1),
#  ('CLAGUE', 1),
#  ('CLAGUE-ROAD', 1),
#  ('E-9', 1),
#  ('N-BRAND', 1),
#  ('BRAND', 1),
#  ('BRAND-BLVD', 1),
#  ('FULTON-STREET', 1),
#  ('#-501', 1),
#  ('S-LAKES', 1),
#  ('LAKES', 1),
#  ('LAKES-DR', 1),
#  ('STE-F', 1),
#  ('BARBARA', 1),
#  ('BARBARA-D', 1),
#  ('D-LANE', 1),
#  ('FORDHAM', 1),
#  ('FORDHAM-RD', 1),
#  ('HILLAND', 1),
#  ('HILLAND-DRIVE', 1),
#  ('WOOSTER', 1),
#  ('WOOSTER-STREET', 1),
#  ('HEAD', 1),
#  ('HEAD-TIDE', 1),
#  ('TIDE', 1),
#  ('TIDE-ROAD', 1),
#  ('SHERMAN-ST', 1),
#  ('SOUTH-SUNRISE', 1),
#  ('SUNRISE', 1),
#  ('SUNRISE-WAY', 1),
#  ('RESTFUL', 1),
#  ('RESTFUL-LN', 1),
#  ('QUAILBROOK', 1),
#  ('QUAILBROOK-DR', 1),
#  ('SOUTHWEST-FRWY', 1),
#  ('FRWY-STE', 1),
#  ('STE-300', 1),
#  ('BROADWAY-,', 1),
#  (',-4TH', 1),
#  ('4TH-FLOOR', 1),
#  ('THOMPSON-AVE', 1),
#  ('EAST-MAPLE', 1),
#  ('MAPLE-ROAD', 1),
#  ('S-LOS', 1),
#  ('LOS-ANGELES', 1),
#  ('ANGELES', 1),
#  ('ANGELES-STREET', 1),
#  ('WEST-26TH', 1),
#  ('26TH', 1),
#  ('26TH-STREET', 1),
#  ('S-STATE', 1),
#  ('STATE-COLLEGE', 1),
#  ('COLLEGE', 1),
#  ('COLLEGE-BLVD', 1),
#  ("O'CONNELL", 1),
#  ("O'CONNELL-CT", 1),
#  ('CT-#', 1),
#  ('COMMERCE-DRIVE', 1),
#  ('GOULD', 1),
#  ('GOULD-STREET', 1),
#  ('SUITE-152', 1),
#  ('INGRID', 1),
#  ('INGRID-RD', 1),
#  ('14504F', 1),
#  ('14504F-LEE', 1),
#  ('LEE', 1),
#  ('LEE-ROAD', 1),
#  ('FOREST-AVE', 1),
#  ('DELAWARE', 1),
#  ('DELAWARE-STREET', 1),
#  ('OLD-MILL', 1),
#  ('MILL', 1),
#  ('MILL-RD', 1),
#  ('146A', 1),
#  ('146A-NORTH', 1),
#  ('NORTH-AVENUE', 1),
#  ('CALLS', 1),
#  ('CALLS-HILL', 1),
#  ('MAPLE-ST', 1),
#  ('SHERMAN-STREET', 1),
#  ('SINCLAIR', 1),
#  ('SINCLAIR-CIR', 1),
#  ('CIR', 1),
#  ('STAFFORD', 1),
#  ('STAFFORD-DRIVE', 1),
#  ('.-37TH', 1),
#  ('37TH-ST', 1),
#  (',-6TH', 1),
#  ('6TH-FLOOR', 1),
#  ('BURBANK', 1),
#  ('BURBANK-BLVD', 1),
#  ('INDUSTRIAL-ROAD', 1),
#  ('RAVINIA-AVENUE', 1),
#  ('EAST-SALEM', 1),
#  ('SALEM', 1),
#  ('SALEM-AVE', 1),
#  ('SUITE-302', 1),
#  ('SCHAUSS', 1),
#  ('SCHAUSS-AVENUE', 1),
#  ('WEST-47TH', 1),
#  ('47TH-ST', 1),
#  ('STE-1807', 1),
#  ('WESTERN-AVE', 1),
#  ('150A', 1),
#  ('150A-ANDOVER', 1),
#  ('ANDOVER', 1),
#  ('ANDOVER-STREET', 1),
#  ('MINNETONKA', 1),
#  ('MINNETONKA-INDUSTRIAL', 1),
#  ('INDUSTRIAL-RD', 1),
#  ('STE-227', 1),
#  ('S-21ST', 1),
#  ('21ST', 1),
#  ('21ST-ST', 1),
#  ('SOUTER', 1),
#  ('WALTHAM', 1),
#  ('WALTHAM-RD', 1),
#  ('GEHMAN', 1),
#  ('GEHMAN-ROAD', 1),
#  ('GREEN-WOODS', 1),
#  ('WOODS', 1),
#  ('WOODS-ROAD', 1),
#  ('RIDING', 1),
#  ('RIDING-PATH', 1),
#  ('PATH', 1),
#  ('PATH-COURT', 1),
#  ('GRAHAM', 1),
#  ('GRAHAM-ST', 1),
#  ('W-13TH', 1),
#  ('13TH-ST', 1),
#  ('UNIT-308', 1),
#  ('D-ROCKFIELD', 1),
#  ('ROCKFIELD', 1),
#  ('ROCKFIELD-BLVD', 1),
#  ('.-TACONY', 1),
#  ('TACONY', 1),
#  ('TACONY-DRIVE', 1),
#  ('WATER-ST', 1),
#  ('THE-ALAMEDA', 1),
#  ('ALAMEDA-STE', 1),
#  ('STE-150', 1),
#  ('BOULDER', 1),
#  ('BOULDER-ST', 1),
#  ('CHELSEA', 1),
#  ('CHELSEA-AVENUE', 1),
#  ('N-4TH', 1),
#  ('4TH-ST', 1),
#  ('STE-H', 1),
#  ('NILES', 1),
#  ('NILES-HILL', 1),
#  ('STATE-RT', 1),
#  ('RT', 1),
#  ('RT-315', 1),
#  ('ABERDEEN', 1),
#  ('ABERDEEN-STREET', 1),
#  ('CLUB-RD', 1),
#  ('HARVARD', 1),
#  ('HARVARD-AVENUE', 1),
#  ('MAPLE-STREET', 1),
#  ('SARATOGA', 1),
#  ('SARATOGA-AVENUE', 1),
#  ('SOUTHBRIDGE-STREET', 1),
#  ('LOCKPORT', 1),
#  ('LOCKPORT-RD', 1),
#  ('.-HARLEM', 1),
#  ('HARLEM-AVENUE', 1),
#  ('GRANITE', 1),
#  ('GRANITE-AVE', 1),
#  ('FILBERT', 1),
#  ('FILBERT-CT', 1),
#  ('COQUINA', 1),
#  ('COQUINA-BAY', 1),
#  ('BAY', 1),
#  ('BAY-LANE', 1),
#  ('SW-UPPER', 1),
#  ('UPPER-BOONES', 1),
#  ('BOONES', 1),
#  ('BOONES-FERRY', 1),
#  ('FERRY', 1),
#  ('FERRY-RD', 1),
#  ('NAOMI', 1),
#  ('NAOMI-CT', 1),
#  ('.-581ST', 1),
#  ('581ST', 1),
#  ('581ST-ST', 1),
#  ('VENTURA', 1),
#  ('VENTURA-BLVD', 1),
#  ('STE-525', 1),
#  ('TEJON', 1),
#  ('TEJON-ST', 1),
#  ('HOLLAND', 1),
#  ('HOLLAND-AVE', 1),
#  ('A-AMEIL', 1),
#  ('AMEIL', 1),
#  ('AMEIL-RD', 1),
#  ('WORCESTER-ROAD', 1),
#  ('ASTON', 1),
#  ('ELMHURST', 1),
#  ('ELMHURST-RD', 1),
#  ('WALTON-RD', 1),
#  ('WOODLAND-DRIVE', 1),
#  ('ROUTE-17M', 1),
#  ('17M', 1),
#  ('17M-W', 1),
#  ('SANFORD', 1),
#  ('SANFORD-RD', 1),
#  ('STRATFORD', 1),
#  ('STRATFORD-AVENUE', 1),
#  ('BELMONT', 1),
#  ('BELMONT-AVE', 1),
#  ('WASHINGTON-RD', 1),
#  ('GORSUCH', 1),
#  ('GORSUCH-AVE', 1),
#  ('ORISKANY', 1),
#  ('ORISKANY-BLVD', 1),
#  ('WARREN-HILL', 1),
#  ('CHEROKEE', 1),
#  ('SADDLE', 1),
#  ('SADDLE-RIDGE', 1),
#  ('RIDGE-CT', 1),
#  ('SUITE-7', 1),
#  ('.-OLD', 1),
#  ('OLD-WOODWARD', 1),
#  ('WOODWARD', 1),
#  ('WOODWARD-AVE', 1),
#  ('SUITE-167', 1),
#  ('LARIMER', 1),
#  ('LARIMER-ST', 1),
#  ('STE-1302', 1),
#  ('CHAMPIONSHIP', 1),
#  ('CHAMPIONSHIP-WAY', 1),
#  ('DIXIE', 1),
#  ('DIXIE-HWY', 1),
#  ('HEMLOCK', 1),
#  ('HEMLOCK-DRIVE', 1),
#  ('SE-1ST', 1),
#  ('1ST-STREET', 1),
#  ('PLEASANTWOOD', 1),
#  ('PLEASANTWOOD-DR', 1),
#  ('HWY-99', 1),
#  ('STE-A', 1),
#  ('SPRINGFIELD-AVE', 1),
#  ('S-CATALINA', 1),
#  ('CATALINA', 1),
#  ('CATALINA-AVE', 1),
#  ('19TH', 1),
#  ('19TH-STREET', 1),
#  ('FLATBUSH', 1),
#  ('FLATBUSH-AVE', 1),
#  ('THUNDERBIRD', 1),
#  ('THUNDERBIRD-AVE', 1),
#  ('ELM', 1),
#  ('ELM-HILL', 1),
#  ('HILL-PIKE', 1),
#  ('PAMPAS', 1),
#  ('PAMPAS-AVE', 1),
#  ('LANCASTER', 1),
#  ('LANCASTER-ST', 1),
#  ('E-PAULARINO', 1),
#  ('PAULARINO', 1),
#  ('PAULARINO-AVENUE', 1),
#  ('OLD-STATESVILLE', 1),
#  ('STATESVILLE', 1),
#  ('STATESVILLE-RD', 1),
#  ('MADRONE', 1),
#  ('MADRONE-PKWY', 1),
#  ('PKWY-#', 1),
#  ('#-100', 1),
#  ('PLEASNTVILLE', 1),
#  ('PLEASNTVILLE-RD', 1),
#  ('COMMERCE-CENTER', 1),
#  ('BROWN', 1),
#  ('BROWN-ROAD', 1),
#  ('PINE-ROAD', 1),
#  ('SHELTON', 1),
#  ('SHELTON-DRIVE', 1),
#  ('E-CARNEGIE', 1),
#  ('CARNEGIE', 1),
#  ('CARNEGIE-AVE', 1),
#  ('UNIT-1M', 1),
#  ('1M', 1),
#  ('S-8TH', 1),
#  ('8TH-STREET', 1),
#  ('WEATHERBEE', 1),
#  ('WEATHERBEE-DRIVE', 1),
#  ('E-14TH', 1),
#  ('14TH-ST', 1),
#  ('FIRST-STREET', 1),
#  ('STE-306', 1),
#  ('SOMERSET', 1),
#  ('SOMERSET-LANE', 1),
#  ('WAUKEGAN', 1),
#  ('WAUKEGAN-RD', 1),
#  ('STE-202', 1),
#  ('CHALMERS', 1),
#  ('CHALMERS-DRIVE', 1),
#  ('W-51', 1),
#  ('BUSINESS', 1),
#  ('BUSINESS-CENTER', 1),
#  ('CENTER-DR', 1),
#  ('STE-6', 1),
#  ('MARLTON', 1),
#  ('MARLTON-PIKE', 1),
#  ('PIKE-E', 1),
#  ('E-STE', 1),
#  ('STE-11', 1),
#  ('HAYES-ROAD', 1),
#  ('RAVINIA-DR', 1),
#  ('STE-500', 1),
#  ('WALL', 1),
#  ('WALL-STREET', 1),
#  ('NASHUA', 1),
#  ('NASHUA-ST', 1),
#  ('SQUADRON', 1),
#  ('SQUADRON-BLVD', 1),
#  ('STE-330', 1),
#  ('WEIDY', 1),
#  ('WEIDY-ROAD', 1),
#  ('ENGLISH-RD', 1),
#  ('WEST-STATE', 1),
#  ('STATE-STREET', 1),
#  ('DIXSON', 1),
#  ('DIXSON-AVE', 1),
#  ('WEST-FULTON', 1),
#  ('DUNBARTON', 1),
#  ('DUNBARTON-DRIVE', 1),
#  ('UTICA', 1),
#  ('UTICA-AVE', 1),
#  ('US-RTE', 1),
#  ('RTE', 1),
#  ('RTE-1', 1),
#  (',-BOX', 1),
#  ('BOX-360', 1),
#  ('CORLIES', 1),
#  ('CORLIES-AVENUE', 1),
#  ('SKOWHEGAN', 1),
#  ('SKOWHEGAN-RD', 1),
#  ('SUITE-355', 1),
#  ('TOMBALL', 1),
#  ('TOMBALL-PARKWAY', 1),
#  ('PARKWAY-,', 1),
#  (',-140', 1),
#  ('PLACENTIA', 1),
#  ('PLACENTIA-AVENUE', 1),
#  ('COLORADO-AVENUE', 1),
#  ('BENNETT', 1),
#  ('BENNETT-RD', 1),
#  ('2060D', 1),
#  ('2060D-AVENIDA', 1),
#  ('AVENIDA', 1),
#  ('AVENIDA-DE', 1),
#  ('DE', 1),
#  ('DE-LOS', 1),
#  ('LOS-ARBOLES', 1),
#  ('ARBOLES', 1),
#  ('ARBOLES-SUITE', 1),
#  ('SUITE-#', 1),
#  ('#-288', 1),
#  ('GOLF-RIDGE', 1),
#  ('RIDGE-CIRCLE', 1),
#  ('EATON', 1),
#  ('EATON-MOUNTAIN', 1),
#  ('MOUNTAIN-RD', 1),
#  ('HARTEL', 1),
#  ('HARTEL-STREET', 1),
#  ('COOMER', 1),
#  ('COOMER-ROAD', 1),
#  ('DOYAL', 1),
#  ('DOYAL-ROAD', 1),
#  ('WELLS', 1),
#  ('WELLS-BRANCH', 1),
#  ('BRANCH', 1),
#  ('BRANCH-PKWY', 1),
#  ('SUITE-6050', 1),
#  ('ST-JOHN', 1),
#  ('JOHN-RD', 1),
#  ('OAKVIEW', 1),
#  ('OAK-INDUSTRIAL', 1),
#  ('INDUSTRIAL-DR', 1),
#  ('DR-NE', 1),
#  ...]

# %%
df_addresses['NEW ADDRESS'].value_counts()
# Out:
# ("", [['DIGIT'], ['ALPHA'], ['WAY'], ['PERIOD']]),                                                 12
# ("", [['DIGIT'], ['LETTER', 'DIR'], ['PERIOD'], ['ALPHA'], ['WAY']]),                              10
# ("", [['DIGIT'], ['ALPHA'], ['WAY', 'PRE'], ['PERIOD']]),                                           6
# ("", [['DIGIT'], ['DIGIT'], ['ALPHA'], ['WAY']]),                                                   5
# ("", [['DIGIT'], ['LETTER'], ['ALPHA'], ['WAY']]),                                                  3
# ("", [['DIGIT'], ['ALPHA'], ['WAY'], ['LETTER', 'DIR'], ['APT'], ['DIGIT']]),                       3
# ("", [['DIGIT'], ['LETTER', 'DIR'], ['PERIOD'], ['ALPHA'], ['WAY', 'PRE'], ['PERIOD']]),            3
# ("", [['DIGIT'], ['ALPHA'], ['WAY'], ['PERIOD'], ['APT'], ['DIGIT']]),                              3
# [['ALPHA'], ['DIGIT']]                                                                              3
# ("", [['DIGIT'], ['ALPHA'], ['ALPHA'], ['WAY'], ['POUND'], ['DIGIT']]),                             2
# ("", [['DIGIT'], ['DIR'], ['ALPHA'], ['WAY'], ['COMMA'], ['APT'], ['DIGIT']]),                      2
# ("", [['DIGIT'], ['LETTER', 'DIR'], ['PERIOD'], ['ALPHA'], ['WAY'], ['PERIOD']]),                   2
# ("", [['DIGIT'], ['LETTER', 'DIR'], ['ALPHA'], ['ALPHA'], ['APT'], ['DIGIT']]),                     2
# ("", [['DIGIT'], ['ALPHA'], ['WAY'], ['DIR'], ['APT'], ['DIGIT']]),                                 2
# ("", [['DIGIT'], ['ALPHA'], ['WAY'], ['COMMA'], ['APT'], ['DIGIT']]),                               2
# ("", [['DIGIT'], ['LETTER', 'DIR'], ['PERIOD'], ['ALPHA'], ['ALPHA'], ['WAY'], ['PERIOD']]),        2
# ("", [['DIGIT'], ['DIGIT'], ['NTH', 'NUMSTR'], ['WAY']]),                                           2
# ("", [['DIGIT'], ['ALPHA'], ['ALPHA'], ['WAY'], ['PERIOD']]),                                       2
# ("", [['DIGIT'], ['ALPHA'], ['WAY', 'PRE'], ['PERIOD'], ['APT'], ['DIGIT']]),                       2
# ("", [['DIGIT'], ['ALPHA'], ['APT'], ['DIGIT']]),                                                   2
# ("", [['DIGIT'], ['ALPHA'], ['ALPHA'], ['WAY'], ['APT'], ['LETTER']]),                              2
# ("", [['DIGIT'], ['ALPHA'], ['ALPHA'], ['ALPHA']]),                                                 2
# [['DIGIT'], [], ['WAY', 'ALPHA']]                                                                   2
# 96 MAIN ST                                                                                          1
# 10096 HART AVE                                                                                      1
# 2402 VICTORY BLVD                                                                                   1
# 2831 CULVER ROAD                                                                                    1
# 125 DONS WAY                                                                                        1
# ("", [['DIGIT'], ['DIR'], ['NTH', 'NUMSTR'], ['WAY'], ['PERIOD'], ['POUND'], ['DIGIT']]),           1
# 336 PINEWOODS RD                                                                                    1
#                                                                                                    ..
# ("", [['DIGIT'], ['DIR'], ['ALPHA'], ['POUND'], ['ALNUM']]),                                        1
# 144 GOULD STREET SUITE 152                                                                          1
# 1600 GOLF ROAD STE 1200                                                                             1
# 8 JACKSON BLVD                                                                                      1
# ("", [['DIGIT'], ['DIR'], ['ALPHA'], ['WAY'], ['POUND'], ['DIGIT'], ['LETTER']]),                   1
# 6 DUMOND ROAD                                                                                       1
# 622 WEST COLORADO STREET                                                                            1
# 285 PIEDMONT ROAD                                                                                   1
# 219 BULIFANTS BOULEVARD                                                                             1
# 1138 HAMILTON NW                                                                                    1
# 520 EAST INDUSTRIAL PARK DRIVE                                                                      1
# 32 SOUTH MALL                                                                                       1
# 8820 MINER ST                                                                                       1
# 294 N WINOOSKI AVE                                                                                  1
# 13601 PROVIDENCE ROAD                                                                               1
# ("", [['DIGIT'], ['LETTER', 'DIR'], ['ALPHA'], ['WAY', 'PRE'], ['POB0'], ['POB2'], ['DIGIT']]),     1
# 133 WATER STREET                                                                                    1
# 2785 FOOTHILL BLVD                                                                                  1
# 16135 COQUINA BAY LANE                                                                              1
# 157 WATER ST                                                                                        1
# 690 AIRPARK ROAD                                                                                    1
# 6799 OAKS RD STE 200                                                                                1
# 89 TRAVER RD                                                                                        1
# 4926 NORTH TRYON STREET                                                                             1
# 2724 COUNTRY CLUB TERRACE                                                                           1
# 4724 OAKSHIRE DR                                                                                    1
# 74 ISLAND POND ROAD                                                                                 1
# 19 BROWN ROAD                                                                                       1
# 13402 GLEN ERICA DRIVE                                                                              1
# 208 EATON MOUNTAIN RD                                                                               1
# Name: NEW ADDRESS, Length: 748, dtype: int64

# %%
paths = sorted([pattern for st, pattern in tuples_training])
print(len(paths))

def convert_to_str_rep(path):
    rep = []
    for sub_lst in path:
        rep.append("-".join(sub_lst))
    return "|".join(rep)

arr_paths = []
for path in paths:
    if len(path) > 0:
        arr_paths.append(convert_to_str_rep(path))
    
#assert len(arr_paths) == len(list(set(arr_paths))), "should be unique"
print("UNIQUE PATHS: ", len(set(arr_paths)))
lst_paths = sorted(list(set(arr_paths)))
for path in set(arr_paths):
    print(path)
# Out:
# 80
# UNIQUE PATHS:  61
# DIGIT|ALPHA|ALPHA|WAY|ADDRESS
# DIGIT|ALPHA|ALPHA|WAY|APT|DIGIT|ADDRESS
# DIGIT|ARTI|ALPHA|ALPHA|ADDRESS
# DIGIT|NTH|WAY|DIR|APT|DIGIT|ADDRESS
# DIGIT|PRE|ALPHA|WAY|ADDRESS
# DIGIT|ALPHA|ALPHA|WAY|DIR|ADDRESS
# DIGIT|NTH|WAY|ALPHA|DIGIT|ADDRESS
# ALNUM|ALPHA|WAY|ADDRESS
# DIGIT|DIR|ALPHA|WAY|ADDRESS
# DIGIT|ALPHA|WAY|POUND|LETTER|ADDRESS
# DIGIT|ALPHA|ALPHA|ADDRESS
# DIGIT|ALPHA|ALPHA|ALPHA|WAY|ADDRESS
# DIGIT|DIR|ALPHA|WAY|POUND|DIGIT|ADDRESS
# DIGIT|ALPHA|DIGIT|ADDRESS
# DIGIT|DIR|WAY|DIGIT|APT|DIGIT|ADDRESS
# DIGIT|WAY|DIGIT|APT|DIGIT|ADDRESS
# DIGIT|DIR|WAY|DIGIT|ADDRESS
# DIGIT|DIR|WAY|LETTER|ADDRESS
# AL_1NUM|DIR|ALPHA|WAY|ADDRESS
# DIGIT|ALPHA|WAY|DIGIT|ADDRESS
# DIGIT|ALPHA|WAY|DIGIT|DIR|ADDRESS
# DIGIT|DIR|ALPHA|WAY|APT|ALNUM|ADDRESS
# DIGIT|DIR|PERIOD|ALPHA|WAY|ADDRESS
# DIGIT|ALPHA|DIR|ADDRESS
# DIGIT|ALPHA|WAY|APT|ALNUM|ADDRESS
# DIGIT|DIR|NUMSTR|WAY|ADDRESS
# DIGIT|ALPHA|ARTI|ALPHA|ADDRESS
# DIGIT|ALPHA|WAY|ALNUM|ADDRESS
# DIGIT|DIR|ALPHA|DIGIT|ADDRESS
# DIGIT|ALPHA|ADDRESS
# DIGIT|ALPHA|ALPHA|WAY|DIR|APT|DIGIT|ADDRESS
# DIGIT|NTH|WAY|ADDRESS
# DIGIT|WAY|DIGIT|ADDRESS
# AL_1NUM|ALPHA|ALPHA|WAY|ADDRESS
# DIGIT|LETTER|ALPHA|WAY|ADDRESS
# DIGIT|ARTI|ALPHA|APT|LETTER|ADDRESS
# DIGIT|DIR|ALPHA|WAY|APT|LETTER|ADDRESS
# DIGIT|NTH|WAY|DIR|ADDRESS
# DIGIT|ALPHA|WAY-PRE|PERIOD|ADDRESS
# DIGIT|DIR|ALPHA|ALPHA|WAY|ADDRESS
# DIGIT|ALPHA|WAY|ADDRESS
# DIGIT|DIR|ALPHA|WAY|DIGIT|ADDRESS
# DIGIT|LETTER-DIR|PERIOD|ALPHA|WAY|ADDRESS
# DIGIT|DIR|ALPHA|ALPHA|WAY|APT|DIGIT|ADDRESS
# DIGIT|ALPHA|WAY|POUND|DIGIT|ADDRESS
# DIGIT|DIR|ALPHA|ADDRESS
# DIGIT|ALPHA|WAY|DIR|ADDRESS
# DIGIT|ALPHA|WAY|APT|DIGIT|ADDRESS
# DIGIT|ARTI|ALPHA|WAY|ADDRESS
# DIGIT|DIR|DIGIT|ALPHA|WAY|ADDRESS
# DIGIT|NUMSTR|WAY|ADDRESS
# DIGIT|WAY|DIGIT|DIR|ADDRESS
# DIGIT|WAY|LETTER|ADDRESS
# DIGIT|WAY|DIGIT|APT|LETTER|ADDRESS
# DIGIT|ALPHA|WAY|APT|LETTER|ADDRESS
# AL_1NUM|NTH|WAY|ADDRESS
# DIGIT|DIR|DIGIT|DIR|ADDRESS
# DIGIT|DIR|ALPHA|WAY|PERIOD|ADDRESS
# DIGIT|NTH|WAY|APT|ALNUM|ADDRESS
# DIGIT|DIR|ALPHA|WAY-PRE|APT|ALNUM|ADDRESS
# DIGIT|DIR|ALPHA|WAY-PRE|POUND|DIGIT|ADDRESS

# %%
lexicon = {
    'WAY': {
        'street': ['st', 'street'],
        'road':  ['rd', 'road'],
        'avenue': ['ave', 'avenue'],
        'court': ['ct']
        },
    'PRE': {
        'saint': ['st']
        },
    'ADDRESS': {
        ':adr'
        },
    'POBOX': {
        ':box'
    },
    'DIGIT': {
        'echo': []
    },
    'ALPHA': {
        'echo': []
    }
    
}

def get_normalized(word, _way, lexicon):
    for entry, lst_matches in lexicon[_way].items():
        if entry == 'echo':
            return word
        if word in lst_matches:
            return entry
    else:
        return None

print(get_normalized('st', 'PRE', lexicon))
print(get_normalized('st', 'WAY', lexicon))
# Out:
# saint
# street

# %%
add = "333 st james st"
print(w(add))
st_lst = w(add)
print(encode_sentence(add))

valid_sequence = [["DIGIT"], ["PRE"], ["ALPHA"], ["WAY"]]
another_valid = [['DIGIT'], ['ALPHA'], ['ALPHA'],['WAY']]
print(valid_sequence)
print(another_valid)
for wrd, typ in zip(st_lst, valid_sequence):
    print(get_normalized(wrd, typ[0], lexicon))
# Out:
# ['333', 'st', 'james', 'st']
# [['DIGIT'], ['WAY', 'PRE', 'ALPHA'], ['ALPHA'], ['WAY', 'PRE', 'ALPHA']]
# [['DIGIT'], ['PRE'], ['ALPHA'], ['WAY']]
# [['DIGIT'], ['ALPHA'], ['ALPHA'], ['WAY']]
# 333
# saint
# james
# street

# %%
seq.reset()
lookaheads = []
st = "333 st james st"
encoded_sequence = encode_sentence(st)
print(st)
print(encoded_sequence)
print('-------------')
for idx in range(len(encoded_sequence)):
    seq.reset()
    for idy, word in enumerate(encoded_sequence):
        seq.hit(word, [],is_learning=False)
        nexts = seq.get_next_values()
        if 'ADDRESS' in nexts:
            print()
            print(idx, idy)
            print(word)
            print(seq.get_active_sequences())
            print(seq.get_next_values())

#print(lookaheads)
# Out:
# 333 st james st
# [['DIGIT'], ['WAY', 'PRE', 'ALPHA'], ['ALPHA'], ['WAY', 'PRE', 'ALPHA']]
# -------------
#
# 0 1
# ['WAY', 'PRE', 'ALPHA']
# ['(*)>DIGIT>ALPHA', '(*)>DIGIT>PRE', '(*)>DIGIT>WAY']
# ['ADDRESS', 'ALPHA', 'ARTI', 'DIGIT', 'DIR', 'LETTER', 'WAY', 'WAY ALPHA']
#
# 0 2
# ['ALPHA']
# ['(*)>DIGIT>ALPHA>ALPHA', '(*)>DIGIT>PRE>ALPHA']
# ['ADDRESS', 'ALPHA', 'WAY']
#
# 0 3
# ['WAY', 'PRE', 'ALPHA']
# ['(*)>DIGIT>ALPHA>ALPHA>ALPHA', '(*)>DIGIT>ALPHA>ALPHA>WAY', '(*)>DIGIT>PRE>ALPHA>WAY']
# ['ADDRESS', 'APT', 'DIR', 'WAY']
#
# 1 1
# ['WAY', 'PRE', 'ALPHA']
# ['(*)>DIGIT>ALPHA', '(*)>DIGIT>PRE', '(*)>DIGIT>WAY']
# ['ADDRESS', 'ALPHA', 'ARTI', 'DIGIT', 'DIR', 'LETTER', 'WAY', 'WAY ALPHA']
#
# 1 2
# ['ALPHA']
# ['(*)>DIGIT>ALPHA>ALPHA', '(*)>DIGIT>PRE>ALPHA']
# ['ADDRESS', 'ALPHA', 'WAY']
#
# 1 3
# ['WAY', 'PRE', 'ALPHA']
# ['(*)>DIGIT>ALPHA>ALPHA>ALPHA', '(*)>DIGIT>ALPHA>ALPHA>WAY', '(*)>DIGIT>PRE>ALPHA>WAY']
# ['ADDRESS', 'APT', 'DIR', 'WAY']
#
# 2 1
# ['WAY', 'PRE', 'ALPHA']
# ['(*)>DIGIT>ALPHA', '(*)>DIGIT>PRE', '(*)>DIGIT>WAY']
# ['ADDRESS', 'ALPHA', 'ARTI', 'DIGIT', 'DIR', 'LETTER', 'WAY', 'WAY ALPHA']
#
# 2 2
# ['ALPHA']
# ['(*)>DIGIT>ALPHA>ALPHA', '(*)>DIGIT>PRE>ALPHA']
# ['ADDRESS', 'ALPHA', 'WAY']
#
# 2 3
# ['WAY', 'PRE', 'ALPHA']
# ['(*)>DIGIT>ALPHA>ALPHA>ALPHA', '(*)>DIGIT>ALPHA>ALPHA>WAY', '(*)>DIGIT>PRE>ALPHA>WAY']
# ['ADDRESS', 'APT', 'DIR', 'WAY']
#
# 3 1
# ['WAY', 'PRE', 'ALPHA']
# ['(*)>DIGIT>ALPHA', '(*)>DIGIT>PRE', '(*)>DIGIT>WAY']
# ['ADDRESS', 'ALPHA', 'ARTI', 'DIGIT', 'DIR', 'LETTER', 'WAY', 'WAY ALPHA']
#
# 3 2
# ['ALPHA']
# ['(*)>DIGIT>ALPHA>ALPHA', '(*)>DIGIT>PRE>ALPHA']
# ['ADDRESS', 'ALPHA', 'WAY']
#
# 3 3
# ['WAY', 'PRE', 'ALPHA']
# ['(*)>DIGIT>ALPHA>ALPHA>ALPHA', '(*)>DIGIT>ALPHA>ALPHA>WAY', '(*)>DIGIT>PRE>ALPHA>WAY']
# ['ADDRESS', 'APT', 'DIR', 'WAY']

# %% [markdown]
# # Next
# * digits that have dashes, and separating those from say 123 17 mile dr.
# * how about all the !DIFF cases
# * put the non-addresses identified into a separate negative test file!
# * clean up code, add tests and move to single file script
# * the dictionary in encode is now a list because we need to preserve order, do not sort it, and also, we need to revistit the order, letter should come after dir etc, because it is more general.
# * after we do that, we need to test the heck out of the output, so include the output of the ['ALPHA'] encoding in the excel sheet for review
# * then get onto testing the separation of po box from address from attn strings
# * then if all goes well, apply this to business name to wrangle in dba selection and also to name fields to identify suffix'
# * and then it's wherever this can find an application.
