# %%
import os
import re
from hydraseq import Hydraseq

# %% [markdown]
# ## basic string breaker "word word2" -> ['word', 'word2']

# %%
def load_category_from_file(fpath):
    """Take a one word per line file and return a regex for the concatenation '^(w1|w2)$'"""
    with open(fpath, 'r') as source:
        ways = [line.strip().lower() for line in source]
    return r'^(' + "|".join(ways) + r')$'

def w(str_sentence):
    return re.findall(r"[\w'/-:]+|[.,!?;#&]", str_sentence)

# %%
seq = Hydraseq('input')

# %% [markdown]
# ## Encoder, takes a single word and returns a list of 'features' characterizing word

# %%
ways = load_category_from_file('ways.csv')
apts = load_category_from_file('apts.csv')
nths = load_category_from_file('nth.csv')
dirs = load_category_from_file('dirs.csv')
arti = load_category_from_file('arti.csv')
pre  = load_category_from_file('pre.csv')
deleg = load_category_from_file('deleg.csv')
print(apts)
def encoder(word, trim=False):
    encodings = [
        ('POBOX', [r'^:box$']),
        ('LETTER', [r'^[a-z]$']),
        ('ALNUM', [r'^(\d+[a-z]+|[a-z]+\d+)[\da-z]*$']),
        ('AL_1NUM', [ r'^\d+[a-z]$' ]),
        ('NTH',    [ nths ]),
        ('ATTN', [r'^:deleg$']),
        ('WAY',  [ ways ]),
        ('DIR',  [ dirs ]),
        ('NUMSTR', [r'^\d+[a-z]+$' ]),
        ('APT', [ apts ]),
        ('DIGIT', [r'^\d+$']),
        ('COMMA', [r'^,$']),
        ('PERIOD', [r'^\.$']),
        ('POUND', [r'^#$']),
        ('DELEG', [r'^attn$', r'^attn:$', r'^c\/o$', r'^co$' ]),
        ('POB0', [r'^po$', r'^p\.o\.$']),
        ('POB2', [r'^box$']),
        ('PRE',  [ pre ]),
        ('ARTI', [ arti ]),
        ('ADDRESS', [r'^:adr$']),
        ('ALPHA', [r'^[a-z]+$']),
    ]
    if not trim:
        return [key for key, rexs in encodings for rex in rexs if re.match(rex, word)]
    else:
        encoding = [key for key, rexs in encodings for rex in rexs if re.match(rex, word)]
        if len(encoding) > 1 and 'ALPHA' in encoding:
            encoding.remove('ALPHA')
        if len(encoding) > 1 and 'ALNUM' in encoding:
            encoding.remove('ALNUM')
        return encoding
# Out:
# ^(apartment|apt|suite|ste|unit|lot|trlr|ro|spc|rm|fl|lbby|pmb|spc|)$

# %%
# THOU SHALL NOT SEQUENCE THREE ALPHAS IN A ROW!
def train_with_provided_list(seq, matrix_lst):
    """matrix list means [['DIGIT'],['ALPHA'],['WAY']] for example"""
    return seq.insert(matrix_lst, is_learning=True).get_next_values()
tuples_training = [
("123 main st",                    [['DIGIT'], ['ALPHA'], ['WAY']]),
("1217 iris ct",                   [['DIGIT'], ['ALPHA'], ['WAY']]),
("123 east main st",               [['DIGIT'], ['DIR'], ['ALPHA'], ['WAY']]),
("310 W MAIN ST",                  [['DIGIT'], ['DIR'], ['ALPHA'], ['WAY']]),
("123 south main street.",         [['DIGIT'], ['DIR'], ['ALPHA'], ['WAY'], ['PERIOD']]),
("90 south park rd",               [['DIGIT'], ['DIR'], ['ALPHA'], ['WAY']]),
("987 el canyon ave",              [['DIGIT'], ['ARTI'], ['ALPHA'], ['WAY']]),
("333 st james st",                [['DIGIT'], ['PRE'], ['ALPHA'], ['WAY']]),
("123 west hill",                  [['DIGIT'], ['DIR'], ['ALPHA']]),
("77 el camino real",              [['DIGIT'], ['ARTI'], ['ALPHA'], ['ALPHA']]),
("1 bay st # b",                   [['DIGIT'], ['ALPHA'], ['WAY'], ['POUND'], ['LETTER']]),
("1 bay rd # b",                   [['DIGIT'], ['ALPHA'], ['WAY'], ['POUND'], ['LETTER']]),
("43 HUDSON AVE # 2",              [['DIGIT'], ['ALPHA'], ['WAY'], ['POUND'], ['DIGIT']]),
("111 san vicente blvd",           [['DIGIT'], ['PRE'], ['ALPHA'], ['WAY']]),
("28 black watch way",             [['DIGIT'], ['ALPHA'], ['ALPHA'], ['WAY']]),
("249 route 206",                  [['DIGIT'], ['WAY'], ['DIGIT']]),
("5500 lost tree",                 [['DIGIT'], ['ALPHA'], ['ALPHA']]),
("996 san benito st",              [['DIGIT'], ['PRE'], ['ALPHA'], ['WAY']]),
("899 embarcadero",                [['DIGIT'], ['ALPHA']]),
("177 montague e",                 [['DIGIT'], ['ALPHA'], ['DIR']]),
("2001 W COURT ST",                [['DIGIT'], ['DIR'], ['ALPHA'], ['WAY']]),
("12545 S HIGHWAY J",              [['DIGIT'], ['DIR'], ['WAY'], ['LETTER']]),
("437 S HIGHWAY 101 STE 501",      [['DIGIT'], ['DIR'], ['WAY'], ['DIGIT'], ['APT'], ['DIGIT']]),
("12940 S HIGHWAY 259",            [['DIGIT'], ['DIR'], ['WAY'], ['DIGIT']]),
("775 E 14 MILE RD",               [['DIGIT'], ['DIR'], ['DIGIT'], ['ALPHA'], ['WAY']]),
("4701 VAN DAM ST",                [['DIGIT'], ['ALPHA'], ['ALPHA'], ['WAY']]),
("3201 NEW MEXICO AVE NW STE 246", [['DIGIT'], ['ALPHA'], ['ALPHA'], ['WAY'], ['DIR'], ['APT'], ['DIGIT']]),
("111 RIO RANCHO BLVD SE",         [['DIGIT'], ['ALPHA'], ['ALPHA'], ['WAY'], ['DIR']]),
("17259 WILD HORSE CREEK RD",      [['DIGIT'], ['ALPHA'], ['ALPHA'], ['ALPHA'], ['WAY']]),
("12587 FAIR LAKES CIR STE 141",   [['DIGIT'], ['ALPHA'], ['ALPHA'], ['WAY'], ['APT'], ['DIGIT']]),
("107 E MARIPOSA DR",              [['DIGIT'], ['DIR'], ['ALPHA'], ['WAY']]),
("401 W FORT WILLIAMS ST",         [['DIGIT'], ['DIR'], ['ALPHA'], ['ALPHA'], ['WAY']]),
("3242 E DESERT INN RD STE 17",    [['DIGIT'], ['DIR'], ['ALPHA'], ['ALPHA'], ['WAY'], ['APT'], ['DIGIT']]),
("14238 44ND AVE",                 [['DIGIT'], ['NUMSTR'], ['WAY']]),
("106 HARVEST HILL LN",            [['DIGIT'], ['ALPHA'], ['ALPHA'], ['WAY']]),
("206 ELMHURST DR APT F15",        [['DIGIT'], ['ALPHA'], ['WAY'], ['APT'], ['ALNUM']]),
("655 COUNTY ROAD 1300",           [['DIGIT'], ['ALPHA'], ['WAY'], ['DIGIT']]),
("50 LOS PATOS WAY",               [['DIGIT'], ['ARTI'], ['ALPHA'], ['WAY']]),
("1001 N 60TH ST",                 [['DIGIT'], ['DIR'], ['NUMSTR'], ['WAY']]),
("5350 S SANTA FE DR",             [['DIGIT'], ['DIR'], ['ALPHA'], ['ALPHA'], ['WAY']]),
("638 18TH ST",                    [['DIGIT'], ['NUMSTR'], ['WAY']]),
("210 E 3RD AVE",                  [['DIGIT'], ['DIR'], ['NUMSTR'], ['WAY']]),
("1390 SW 160TH AVE",              [['DIGIT'], ['DIR'], ['NUMSTR'], ['WAY']]),
("171 NE 212TH ST",                [['DIGIT'], ['DIR'], ['NUMSTR'], ['WAY']]),
("712 B MAIN ST",                  [['DIGIT'], ['LETTER'], ['ALPHA'], ['WAY']]),
("2060 B MOUNTAIN BLVD",           [['DIGIT'], ['LETTER'], ['ALPHA'], ['WAY']]),
("123 avenue c",                   [['DIGIT'], ['WAY'], ['LETTER']]),
("717B GRAVES ST",                 [['ALNUM'], ['ALPHA'], ['WAY']]),
("1234 7TH AVENUE",                [['DIGIT'], ['NTH'], ['WAY']]),
("205 3RD AVE APT 3K",             [['DIGIT'], ['NTH'], ['WAY'], ['APT'], ['ALNUM']]),
("462 7TH AVE FL 2",               [['DIGIT'], ['NTH'], ['WAY'], ['ALPHA'], ['DIGIT']]),
    ("219 2ND AVE SE STE 101",     [['DIGIT'], ['NTH'], ['WAY'], ['DIR'], ['APT'], ['DIGIT']]),
    ("10859 12TH AVE SW",          [['DIGIT'], ['NTH'], ['WAY'], ['DIR']]),
    ("4401 LOOP 322",              [['DIGIT'], ['ALPHA'], ['DIGIT']]),
    ("8690 EDGE OF TEXAS",         [['DIGIT'], ['ALPHA'], ['ARTI'], ['ALPHA']]),
    ("487 RITCHIE HWY B102",       [['DIGIT'], ['ALPHA'], ['WAY'], ['ALNUM']]),
    ("366 RAILROAD AVE LOT 31", [['DIGIT'], ['ALPHA'], ['WAY'], ['APT'], ['DIGIT']]),
    ("1631A S MAIN ST",         [['AL_1NUM'],['DIR'],['ALPHA'],['WAY']]),
    ("338A 7TH AVE", [['AL_1NUM'],['NTH'],['WAY']]),
    #("3RD ST", [['NTH'],['WAY']]), THIS IS IN INCOPLETE ADDRESS
    ("1771A PRINCESS ANNE RD", [['AL_1NUM'], ['ALPHA'], ['ALPHA'], ['WAY']]),
    ("751 ROUTE 37 W", [['DIGIT'], ['WAY'], ['DIGIT'], ['DIR']]),
    ("73140 HIGHWAY 111 STE 6", [['DIGIT'], ['WAY'], ['DIGIT'], ['APT'], ['DIGIT']]),
    ("476534 HIGHWAY 95 STE A", [['DIGIT'], ['WAY'], ['DIGIT'], ['APT'], ['LETTER']]),
    ("225 LA PALOMA APT A", [['DIGIT'], ['ARTI'], ['ALPHA'], ['APT'], ['LETTER']]), # DIFF!
    ("3200 SISK RD STE C", [['DIGIT'], ['ALPHA'], ['WAY'], ['APT'], ['LETTER']]), # DIFF!
    ("2584 US HIGHWAY 80 W", [['DIGIT'], ['ALPHA'], ['WAY'], ['DIGIT'], ['DIR']]), # DIFF!
    ("2387 PORTOLA RD STE A", [['DIGIT'], ['ALPHA'], ['WAY'], ['APT'], ['LETTER']]), # DIFF!
    ("118 N 300 W", [['DIGIT'], ['DIR'], ['DIGIT'], ['DIR']]),
    ("1027 S WESTERN AVE # 2", [['DIGIT'], ['DIR'], ['ALPHA'], ['WAY'], ['POUND'], ['DIGIT']]),
    ("690 S STATE HIGHWAY 5", [['DIGIT'], ['DIR'], ['ALPHA'], ['WAY'], ['DIGIT']]),
    ("3070 W CHAPMAN AVE STE A", [['DIGIT'], ['DIR'], ['ALPHA'], ['WAY'], ['APT'], ['LETTER']]),
    ("1420 E PLAZA BLVD STE D5", [['DIGIT'], ['DIR'], ['ALPHA'], ['WAY'], ['APT'], ['ALNUM']]),
    ("82 S MAIN ST # 2", [['DIGIT'], ['DIR'], ['ALPHA'], ['WAY', 'PRE'], ['POUND'], ['DIGIT']]),
    ("473 S MAIN ST STE A", [['DIGIT'], ['DIR'], ['ALPHA'], ['WAY'], ['APT'], ['LETTER']]),
    ("1029 W BATTLEFIELD ST APT E214", [['DIGIT'], ['DIR'], ['ALPHA'], ['WAY', 'PRE'], ['APT'],['ALNUM']]),
    ("3843 S BRISTOL 213", [['DIGIT'], ['DIR'], ['ALPHA'], ['DIGIT']]),
]
for ts, matrix_lst in tuples_training:
    matrix_lst.append(['ADDRESS'])
    train_with_provided_list(seq, matrix_lst)

# valid po box
train_samples = [
    ("po box 1234", [['POB0'],['POB2'],['DIGIT']]),
    ("box 999",      [['POB2'],['DIGIT']]),
]
for ts, matrix_lst in train_samples:
    matrix_lst.append(['POBOX'])
    train_with_provided_list(seq, matrix_lst)

# valid attn
train_samples = [
    ("c/o john smith",     [['DELEG'],['ALPHA'],['ALPHA']]),
    ("attn john smith",    [['DELEG'],['ALPHA'],['ALPHA']]),
    ("attn: john smith",   [['DELEG'],['ALPHA'],['ALPHA']]),
    ("c/o john",           [['DELEG'],['ALPHA']]),
]
for ts, matrix_lst in train_samples:
    matrix_lst.append(['ATTN'])
    train_with_provided_list(seq, matrix_lst)

# %%
def encode_from_word_list(arr_st):
    """Expects ['123', 'main', 'st]"""
    assert isinstance(arr_st, list)
    if arr_st: assert isinstance(arr_st[0], str)
    return [encoder(word) for word in arr_st]

def is_address(seq, arr_st):
    """Expects ["123","main","st"]"""
    return any([pred == 'ADDRESS' for pred in seq.look_ahead(encode_from_word_list(arr_st)).get_next_values()])

def is_pobox(seq, arr_st):
    """Expects ["123","main","st"]"""
    assert isinstance(arr_st, list)
    return any([pred == 'POBOX' for pred in seq.look_ahead(encode_from_word_list(arr_st)).get_next_values()])

sent = "po box 7001"
assert is_pobox(seq, w(sent)) == True

def is_deleg(seq, arr_st):
    """Expects ["123","main","st"]"""
    assert isinstance(arr_st, list)
    return any([pred == 'ATTN' for pred in seq.look_ahead(encode_from_word_list(arr_st)).get_next_values()])

sent = "attn john doe"
assert is_deleg(seq, w(sent)) == True

# %%
# %%time
def get_markers(seq, sent, lst_targets):
    """Input is like '123 main str' and returns a list of lists"""
    arr_w = w(sent)
    idx_tail = len(arr_w)
    markers = []
    for idx_beg in range(idx_tail):
        for idx_end in range(idx_beg + 1, idx_tail +1):
            next_values = seq.look_ahead(encode_from_word_list(arr_w[idx_beg:idx_end])).get_next_values()
            matches = list(set(next_values) & set(lst_targets) )
            if matches:
                markers.append([idx_beg, idx_end, idx_end - idx_beg, matches, ' '.join(arr_w[idx_beg:idx_end])])
    return markers


#st = "c/o john smith 100 maple ave"
st = "333 st james st"
get_markers(seq, st, ['ADDRESS'])
# Out:
# CPU times: user 989 µs, sys: 36 µs, total: 1.03 ms
# Wall time: 1.06 ms

# %%
def return_max_address(seq, sent):
    sent = str(sent).lower().strip()
    arr_cands = get_markers(seq, sent, ['ADDRESS'])
    if not arr_cands:
        return str([encoder(word) for word in w(sent)])
    
    max_len = 0
    for cand in arr_cands:
        if cand[2] > max_len:
            max_len = cand[2]
            candidate_address = cand[4]
    
    candidate_address = candidate_address.upper()
    if candidate_address != sent.upper():
        return '("", {}),'.format(str([encoder(word, trim=True) for word in w(sent)]))
    else:
        return candidate_address

return_max_address(seq, "16w661 90th st")
# Out:
# "[['ALNUM'], ['ALNUM', 'NTH', 'NUMSTR'], ['WAY', 'PRE', 'ALPHA']]"

# %%
field1 = "280 NW 123RD LN"
field2 = "288 NE 53RD ST"
print(return_max_address(seq, field2))
# Out:
# 288 NE 53RD ST

# %%
import pandas as pd

# %%
df = pd.read_csv('originals.csv')

# %%
df_addresses = df[['ACCT_STREET_ADDR']]
df_addresses.drop_duplicates(keep='first', inplace=True)
# Out:
# /Users/niarfe/env3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# %%time
df_addresses['NEW ADDRESS'] = df_addresses['ACCT_STREET_ADDR'].apply(lambda x: return_max_address(seq, x))
# Out:
# CPU times: user 40.9 s, sys: 302 ms, total: 41.2 s
# Wall time: 41.6 s
# /Users/niarfe/env3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_addresses.head()
# Out:
#          ACCT_STREET_ADDR             NEW ADDRESS
# 0  11706 SAN VICENTE BLVD  11706 SAN VICENTE BLVD
# 1      28 BLACK WATCH WAY      28 BLACK WATCH WAY
# 2           385 S MAIN ST           385 S MAIN ST
# 3     7808 CHASEWOOD LOOP     7808 CHASEWOOD LOOP
# 4       996 SAN BENITO ST       996 SAN BENITO ST

# %%
df_addresses.to_csv('processed_addresses.csv')
! open 'processed_addresses.csv'

# %%
from collections import Counter
wcount = Counter()

def count_words(ctr, st):
    arr_words = w(st)
    for idx, word in enumerate(arr_words):
        if not word.isdigit():
            ctr[word] += 1
            bigram = arr_words[idx:idx+2]
            #print(arr_words[idx:idx+2])
            if len(bigram) == 2:
                ctr["-".join(bigram)] += 1
    return st

df_addresses['ACCT_STREET_ADDR'].apply(lambda x: count_words(wcount, x))
wcount.most_common()
# Out:
# [('ST', 10932),
#  ('AVE', 8265),
#  ('RD', 7797),
#  ('DR', 5148),
#  ('STE', 5006),
#  ('W', 3286),
#  ('S', 3177),
#  ('E', 3153),
#  ('BLVD', 3029),
#  ('N', 2990),
#  ('BOX', 2101),
#  ('PO', 2092),
#  ('PO-BOX', 2092),
#  ('LN', 1653),
#  ('MAIN', 1363),
#  ('MAIN-ST', 1306),
#  ('CT', 1132),
#  ('RD-STE', 1009),
#  ('APT', 987),
#  ('ST-STE', 924),
#  ('WAY', 861),
#  ('AVE-STE', 846),
#  ('HIGHWAY', 750),
#  ('HWY', 731),
#  ('#', 704),
#  ('BLVD-STE', 648),
#  ('PL', 561),
#  ('CIR', 545),
#  ('A', 520),
#  ('UNIT', 504),
#  ('B', 472),
#  ('DR-STE', 467),
#  ('NW', 466),
#  ('PKWY', 454),
#  ('NE', 453),
#  ('STATE', 435),
#  ('PARK', 434),
#  ('BROADWAY', 414),
#  ('SW', 362),
#  ('ROUTE', 343),
#  ('SE', 333),
#  ('HILL', 310),
#  ('STE-A', 299),
#  ('LAKE', 295),
#  ('WASHINGTON', 286),
#  ('CREEK', 284),
#  ('OLD', 272),
#  ('C', 270),
#  ('VALLEY', 265),
#  ('STE-B', 265),
#  ('ST-APT', 256),
#  ('ROAD', 246),
#  ('US', 246),
#  ('OAK', 224),
#  ('RIVER', 223),
#  ('TRL', 222),
#  ('COUNTY', 218),
#  ('D', 209),
#  ('US-HIGHWAY', 209),
#  ('SAN', 200),
#  ('RIDGE', 195),
#  ('N-MAIN', 193),
#  ('3RD', 193),
#  ('AVE-APT', 193),
#  ('HILL-RD', 190),
#  ('E-MAIN', 189),
#  ('S-MAIN', 184),
#  ('PIKE', 178),
#  ('STE-C', 178),
#  ('CENTRAL', 174),
#  ('2ND', 169),
#  ('W-MAIN', 169),
#  ('CENTER', 169),
#  ('COUNTY-ROAD', 158),
#  ('BEACH', 158),
#  ('EL', 157),
#  ('4TH', 156),
#  ('1ST', 153),
#  ('STE-101', 149),
#  ('STE-100', 149),
#  ('WASHINGTON-ST', 148),
#  ('PKWY-STE', 146),
#  ('STE-D', 146),
#  ('GRAND', 144),
#  ('STATE-ROUTE', 141),
#  ('GROVE', 141),
#  ('DR-APT', 140),
#  ('RD-#', 139),
#  ('AVE-#', 137),
#  ('ST-#', 136),
#  ('CANYON', 135),
#  ('BROAD', 134),
#  ('NEW', 133),
#  ('MARKET', 132),
#  ('MILL', 131),
#  ('5TH', 128),
#  ('LA', 128),
#  ('TER', 127),
#  ('SANTA', 124),
#  ('CHURCH', 124),
#  ('LINCOLN', 123),
#  ('BROAD-ST', 123),
#  ('ST-UNIT', 123),
#  ('STE-1', 119),
#  ('CAMINO', 119),
#  ('6TH', 118),
#  ('RD-APT', 118),
#  ('ST-NW', 117),
#  ('STE-102', 117),
#  ('PARK-AVE', 116),
#  ('LOOP', 115),
#  ('VIEW', 115),
#  ('4TH-ST', 114),
#  ('SPRING', 114),
#  ('CENTRAL-AVE', 114),
#  ('SOUTH', 112),
#  ('3RD-ST', 112),
#  ('7TH', 112),
#  ('JEFFERSON', 111),
#  ('UNIVERSITY', 110),
#  ('MARKET-ST', 108),
#  ('G', 108),
#  ('F', 108),
#  ('STATE-ST', 107),
#  ('SAINT', 107),
#  ('AVENUE', 106),
#  ('SUNSET', 106),
#  ('TPKE', 105),
#  ('CREEK-RD', 105),
#  ('MADISON', 104),
#  ('FOREST', 104),
#  ('2ND-ST', 103),
#  ('SPRINGS', 102),
#  ('BLVD-#', 102),
#  ('1ST-ST', 102),
#  ('FM', 100),
#  ('STE-E', 99),
#  ('VISTA', 99),
#  ('POST', 98),
#  ('STATE-HIGHWAY', 98),
#  ('VILLAGE', 97),
#  ('NORTH', 97),
#  ('WEST', 97),
#  ('MOUNTAIN', 95),
#  ('WALNUT', 94),
#  ('DEL', 93),
#  ('CEDAR', 93),
#  ('9TH', 92),
#  ('GREEN', 91),
#  ('UNION', 91),
#  ('PINE', 91),
#  ('BROADWAY-ST', 89),
#  ('PLZ', 89),
#  ('BAY', 88),
#  ('MAPLE', 87),
#  ('STE-103', 87),
#  ('H', 87),
#  ('PLEASANT', 87),
#  ('OAKS', 87),
#  ('VAN', 86),
#  ('EL-CAMINO', 86),
#  ('BRIDGE', 86),
#  ('MILE', 86),
#  ('6TH-ST', 85),
#  ('MALL', 85),
#  ('PACIFIC', 85),
#  ('HIGH', 84),
#  ('KING', 84),
#  ('LN-STE', 84),
#  ('REAL', 84),
#  ('RIVER-RD', 84),
#  ('COUNTRY', 83),
#  ('8TH', 82),
#  ('WESTERN', 82),
#  ('STE-2', 82),
#  ('FL', 81),
#  ('BEACH-BLVD', 81),
#  ('WAY-STE', 81),
#  ('POINT', 80),
#  ('CAMINO-REAL', 80),
#  ('VALLEY-RD', 80),
#  ('COAST', 79),
#  ('POST-RD', 78),
#  ('PARK-DR', 78),
#  ('7TH-ST', 78),
#  ('MILE-RD', 78),
#  ('FRANKLIN', 77),
#  ('AVE-UNIT', 77),
#  ('5TH-ST', 77),
#  ('MISSION', 76),
#  ('ELM', 76),
#  ('COLLEGE', 76),
#  ('S-BROADWAY', 76),
#  ('10TH', 75),
#  ('ATLANTIC', 75),
#  ('HIGHLAND', 75),
#  ('RUN', 73),
#  ('3RD-AVE', 73),
#  ('RD-UNIT', 73),
#  ('JACKSON', 73),
#  ('SQ', 73),
#  ('ROCK', 73),
#  ('STE-G', 72),
#  ('WESTERN-AVE', 72),
#  ('BOSTON', 71),
#  ('STE-105', 71),
#  ('AVE-S', 70),
#  ('FOOTHILL', 70),
#  ('CTR', 70),
#  ('CHESTNUT', 70),
#  ('OCEAN', 69),
#  ('AVE-NW', 69),
#  ('WASHINGTON-AVE', 69),
#  ('EAST', 69),
#  ('STE-F', 69),
#  ('#-A', 68),
#  ('HWY-STE', 68),
#  ('CHURCH-ST', 68),
#  ('RIDGE-RD', 68),
#  ('MILL-RD', 68),
#  ('J', 67),
#  ('STE-104', 67),
#  ('HILLS', 67),
#  ('VENTURA', 67),
#  ('GRAND-AVE', 67),
#  ('STREET', 66),
#  ('CREEK-DR', 66),
#  ('WHITE', 66),
#  ('11TH', 65),
#  ('YORK', 65),
#  ('9TH-ST', 65),
#  ('12TH', 64),
#  ('FOOTHILL-BLVD', 64),
#  ('VALLEY-BLVD', 64),
#  ('PLAZA', 64),
#  ('COAST-HWY', 63),
#  ('VIA', 63),
#  ('LAKE-RD', 63),
#  ('GLEN', 63),
#  ('DE', 62),
#  ('WILLOW', 62),
#  ('STE-200', 61),
#  ('TOWN', 61),
#  ('2ND-AVE', 60),
#  ('CYPRESS', 60),
#  ('CANYON-RD', 59),
#  ('MOUNT', 59),
#  ('8TH-ST', 59),
#  ('STE-120', 59),
#  ('STE-110', 59),
#  ('LONG', 58),
#  ('INDUSTRIAL', 58),
#  ('STE-4', 58),
#  ('STE-3', 58),
#  ('DR-#', 58),
#  ('MADISON-AVE', 57),
#  ('VENTURA-BLVD', 57),
#  ('K', 57),
#  ('MAGNOLIA', 57),
#  ('FRONT', 57),
#  ('MEMORIAL', 56),
#  ('M', 56),
#  ('FERRY', 56),
#  ('STE-106', 56),
#  ('MEADOW', 56),
#  ('LOS', 55),
#  ('ROOSEVELT', 55),
#  ('BLVD-APT', 55),
#  ('AVE-N', 55),
#  ('GARDEN', 55),
#  ('FORT', 54),
#  ('LAUREL', 53),
#  ('RANCH', 53),
#  ('FWY', 53),
#  ('ST-NE', 53),
#  ('FRONT-ST', 53),
#  ('I', 52),
#  ('PALM', 52),
#  ('STE-150', 52),
#  ('12TH-ST', 51),
#  ('17TH', 51),
#  ('1/2', 51),
#  ('RD-NE', 51),
#  ('DR-UNIT', 50),
#  ('HIGH-ST', 50),
#  ('ISLAND', 50),
#  ('ATLANTIC-AVE', 50),
#  ('FARM', 50),
#  ('SPRINGS-RD', 50),
#  ('LINE', 50),
#  ('COMMERCE', 49),
#  ('SOUTH-ST', 49),
#  ('RIDGE-DR', 49),
#  ('ELM-ST', 49),
#  ('13TH', 49),
#  ('MESA', 49),
#  ('WALNUT-ST', 49),
#  ('RIVERSIDE', 48),
#  ('JOHN', 48),
#  ('BLVD-UNIT', 48),
#  ('LEE', 48),
#  ('LIBERTY', 48),
#  ('11TH-ST', 48),
#  ('BROOK', 48),
#  ('SUNRISE', 48),
#  ('5TH-AVE', 47),
#  ('TREE', 47),
#  ('16TH', 47),
#  ('CLUB', 47),
#  ('HARBOR', 47),
#  ('CENTER-DR', 47),
#  ('CHESTNUT-ST', 47),
#  ('HAMILTON', 47),
#  ('LINCOLN-AVE', 47),
#  ('ST-SE', 46),
#  ('APT-2', 46),
#  ('SHORE', 46),
#  ('CV', 46),
#  ('#-B', 46),
#  ('INDIAN', 46),
#  ('STE-7', 46),
#  ('S-STATE', 46),
#  ('BLUE', 46),
#  ('1ST-AVE', 46),
#  ('LAS', 46),
#  ('AVE-NE', 45),
#  ('N-BROADWAY', 45),
#  ('NE-STE', 45),
#  ('OAK-ST', 45),
#  ('APT-B', 45),
#  ('MARTIN', 45),
#  ('AVE-SE', 45),
#  ('JOHNSON', 45),
#  ('PEACHTREE', 44),
#  ('STE-108', 44),
#  ('WATER', 44),
#  ('STE-6', 44),
#  ('UNIVERSITY-AVE', 44),
#  ('PARK-BLVD', 44),
#  ('COLUMBIA', 44),
#  ('KINGS', 44),
#  ('MONROE', 44),
#  ('ST-FL', 44),
#  ('LINE-RD', 44),
#  ('DAVIS', 44),
#  ('14TH', 44),
#  ('10TH-ST', 44),
#  ('GRANT', 43),
#  ('CHURCH-RD', 43),
#  ('AIRPORT', 43),
#  ('FULTON', 43),
#  ('S-WESTERN', 43),
#  ('SCHOOL', 43),
#  ('HOLLOW', 43),
#  ('ST-N', 43),
#  ('STE-107', 43),
#  ('&', 43),
#  ('SILVER', 42),
#  ('WILSHIRE', 42),
#  ('HIGHLAND-AVE', 42),
#  ('JACKSON-ST', 42),
#  ('ORCHARD', 42),
#  ('APT-1', 42),
#  ('PROSPECT', 42),
#  ('LN-APT', 42),
#  ('UNIT-A', 42),
#  ('VIRGINIA', 42),
#  ('CHERRY', 41),
#  ('W-6TH', 41),
#  ('CAMPBELL', 41),
#  ('AVE-SW', 41),
#  ('LAFAYETTE', 41),
#  ('W-STE', 41),
#  ('4TH-AVE', 41),
#  ('WASHINGTON-BLVD', 41),
#  ('STE-300', 40),
#  ('17TH-ST', 40),
#  ('BOSTON-POST', 40),
#  ('RED', 40),
#  ('LAKE-DR', 40),
#  ('SPRING-ST', 40),
#  ('CENTER-ST', 40),
#  ('14TH-ST', 40),
#  ('ST-S', 40),
#  ('PASEO', 40),
#  ('CHAPMAN', 39),
#  ('SANTA-FE', 39),
#  ('FE', 39),
#  ('CLARK', 39),
#  ('CALIFORNIA', 39),
#  ('ST-E', 39),
#  ('PIONEER', 39),
#  ('ST-SW', 39),
#  ('JEFFERSON-ST', 39),
#  ('COURT', 39),
#  ('FALLS', 39),
#  ('SIERRA', 39),
#  ('S-STE', 39),
#  ('L', 38),
#  ('MISSION-ST', 38),
#  ('18TH', 38),
#  ('WILSHIRE-BLVD', 38),
#  ('MADISON-ST', 38),
#  ('STE-5', 38),
#  ('ADAMS', 38),
#  ('ST-W', 38),
#  ('BRIDGE-ST', 38),
#  ('CITY', 38),
#  ('WOOD', 38),
#  ('FRANKLIN-ST', 37),
#  ('BEND', 37),
#  ('FERRY-RD', 37),
#  ('SQUARE', 37),
#  ('BELL', 37),
#  ('BALTIMORE', 37),
#  ('RAILROAD', 37),
#  ('WILLIAMS', 37),
#  ('RIVER-AVE', 37),
#  ('GEORGE', 37),
#  ('STE-130', 37),
#  ('ROSE', 37),
#  ('APT-3', 37),
#  ('HAWTHORNE', 36),
#  ('APT-A', 36),
#  ('COVE', 36),
#  ('STE-H', 36),
#  ('SPRUCE', 36),
#  ('RICHMOND', 36),
#  ('E-BROADWAY', 36),
#  ('DEER', 36),
#  ('EASTERN', 35),
#  ('POND', 35),
#  ('N-STE', 35),
#  ('STE-J', 35),
#  ('RANCHO', 35),
#  ('LOT', 35),
#  ('BLDG', 35),
#  ('16TH-ST', 35),
#  ('OLIVE', 35),
#  ('GROVE-BLVD', 35),
#  ('EAGLE', 35),
#  ('LITTLE', 35),
#  ('GROVE-RD', 35),
#  ('PINE-ST', 35),
#  ('SHERIDAN', 35),
#  ('TELEGRAPH', 35),
#  ('BLVD-S', 35),
#  ('E-WASHINGTON', 34),
#  ('OF', 34),
#  ('#-1', 34),
#  ('28TH', 34),
#  ('STE-201', 34),
#  ('BEVERLY', 34),
#  ('YORK-RD', 34),
#  ('FAIR', 34),
#  ('HARRISON', 34),
#  ('SMITH', 34),
#  ('POPLAR', 34),
#  ('IRVING', 34),
#  ('PARK-RD', 34),
#  ('LAKEVIEW', 34),
#  ('BRANCH', 34),
#  ('PENNSYLVANIA', 34),
#  ('COLORADO', 34),
#  ('FEDERAL', 34),
#  ('MAPLE-AVE', 33),
#  ('NORTHWEST', 33),
#  ('THE', 33),
#  ('UNIT-B', 33),
#  ('HOWARD', 33),
#  ('MANOR', 33),
#  ('WATER-ST', 33),
#  ('E-STE', 33),
#  ('PICO', 33),
#  ('JEFFERSON-AVE', 33),
#  ('STE-109', 33),
#  ('CROSSING', 33),
#  ('W-SUNSET', 33),
#  ('SE-STE', 33),
#  ('CROSS', 33),
#  ('SPC', 33),
#  ('PRESTON', 33),
#  ('NORTH-AVE', 33),
#  ('SHERMAN', 33),
#  ('THOMAS', 33),
#  ('LEWIS', 32),
#  ('WILSON', 32),
#  ('PEARL', 32),
#  ('24TH', 32),
#  ('EUCLID', 32),
#  ('21ST', 32),
#  ('WINCHESTER', 32),
#  ('NATIONAL', 32),
#  ('COMMERCIAL', 32),
#  ('DIVISION', 32),
#  ('MONTE', 32),
#  ('VIEW-DR', 32),
#  ('36TH', 32),
#  ('DOUGLAS', 32),
#  ('LANCASTER', 32),
#  ('15TH', 32),
#  ('UNION-ST', 32),
#  ('WARREN', 32),
#  ('AVE-W', 32),
#  ('MOUNTAIN-RD', 31),
#  ('LAKE-ST', 31),
#  ('HAVEN', 31),
#  ('RAINBOW', 31),
#  ('HILLSIDE', 31),
#  ('CANYON-DR', 31),
#  ('W-STATE', 31),
#  ('LEXINGTON', 31),
#  ('MIDDLE', 31),
#  ('CLINTON', 31),
#  ('OAK-DR', 31),
#  ('MEADOWS', 31),
#  ('DR-NE', 31),
#  ('BLACK', 30),
#  ('10TH-AVE', 30),
#  ('CIR-STE', 30),
#  ('HIGHWAY-9', 30),
#  ('WILLIAM', 30),
#  ('N-STATE', 30),
#  ('BRIDGE-RD', 30),
#  ('RD-NW', 30),
#  ('RD-W', 30),
#  ('POINTE', 30),
#  ('20TH', 30),
#  ('STE-10', 30),
#  ('SUMMIT', 30),
#  ('S-WASHINGTON', 30),
#  ('PACIFIC-COAST', 30),
#  ('STE-8', 30),
#  ('HEIGHTS', 30),
#  ('MICHIGAN', 30),
#  ('VICTORY', 30),
#  ('CREST', 30),
#  ('SUNSET-BLVD', 30),
#  ('OAKS-BLVD', 30),
#  ('NW-STE', 30),
#  ('CHAPEL', 30),
#  ('HILL-DR', 30),
#  ('IMPERIAL', 30),
#  ('ORANGE', 30),
#  ('25TH', 29),
#  ('SHAW', 29),
#  ('COUNTRY-RD', 29),
#  ('KING-ST', 29),
#  ('TEXAS', 29),
#  ('CT-STE', 29),
#  ('CHAPMAN-AVE', 29),
#  ('CHARLES', 29),
#  ('SEPULVEDA', 29),
#  ('SEPULVEDA-BLVD', 29),
#  ('OLYMPIC', 29),
#  ('7TH-AVE', 29),
#  ('NEWPORT', 29),
#  ('23RD', 29),
#  ('AVENIDA', 29),
#  ('PICO-BLVD', 29),
#  ('MAGNOLIA-AVE', 29),
#  ('BEDFORD', 29),
#  ('FL-2', 28),
#  ('STONE', 28),
#  ('WESTMINSTER', 28),
#  ('WOODS', 28),
#  ('PL-STE', 28),
#  ('EXPY', 28),
#  ('PASS', 28),
#  ('GOLDEN', 28),
#  ('DR-NW', 28),
#  ('E-STATE', 28),
#  ('PARK-ST', 28),
#  ('UNIVERSITY-DR', 28),
#  ('26TH', 28),
#  ('CONGRESS', 28),
#  ('HORSE', 28),
#  ('MILL-ST', 28),
#  ('6TH-AVE', 28),
#  ('BELMONT', 28),
#  ('MAIN-AVE', 28),
#  ('GRAND-RIVER', 28),
#  ('LOCUST', 28),
#  ('AVE-E', 28),
#  ('W-WASHINGTON', 28),
#  ('INTERNATIONAL', 28),
#  ('WAY-APT', 28),
#  ('GREEN-ST', 28),
#  ('STE-K', 28),
#  ('LANDING', 27),
#  ('E-4TH', 27),
#  ('18TH-ST', 27),
#  ('HOLLYWOOD', 27),
#  ('CANAL', 27),
#  ('LAKE-AVE', 27),
#  ('GATEWAY', 27),
#  ('COLLEGE-AVE', 27),
#  ('STE-112', 27),
#  ('INTERSTATE', 27),
#  ('FOREST-DR', 27),
#  ('TRAIL', 27),
#  ('MEMORIAL-DR', 27),
#  ('19TH', 27),
#  ('EASTERN-AVE', 27),
#  ('CALLE', 27),
#  ('ROYAL', 27),
#  ('DR-SE', 27),
#  ('32ND', 27),
#  ('MORRIS', 27),
#  ('PACIFIC-AVE', 27),
#  ('ROW', 27),
#  ('SOUTHERN', 27),
#  ('FARM-RD', 27),
#  ('BRISTOL', 26),
#  ('RIVERSIDE-DR', 26),
#  ('VILLAGE-DR', 26),
#  ('WOODLAND', 26),
#  ('ESSEX', 26),
#  ('CIRCLE', 26),
#  ('PEARL-ST', 26),
#  ('STE-I', 26),
#  ('ALLEN', 26),
#  ('FWY-STE', 26),
#  ('FAIRFIELD', 26),
#  ('DIVISION-ST', 26),
#  ('SAN-FERNANDO', 26),
#  ('FERNANDO', 26),
#  ('VALLEY-DR', 26),
#  ('OAKS-DR', 26),
#  ('STE-111', 26),
#  ('MICHIGAN-AVE', 26),
#  ('HICKORY', 26),
#  ('PARKER', 26),
#  ('MONICA', 26),
#  ('HILLS-DR', 26),
#  ('REDWOOD', 26),
#  ('STE-12', 26),
#  ('STE-400', 26),
#  ('LUTHER', 26),
#  ('DIXIE', 26),
#  ('BROADWAY-STE', 26),
#  ('STE-140', 26),
#  ('MILITARY', 25),
#  ('STE-202', 25),
#  ('RIVER-ST', 25),
#  ('FULTON-ST', 25),
#  ('29TH', 25),
#  ('MASSACHUSETTS', 25),
#  ('RD-SE', 25),
#  ('CAPITOL', 25),
#  ('HERITAGE', 25),
#  ('MACARTHUR', 25),
#  ('COUNTRY-CLUB', 25),
#  ('RANCH-RD', 25),
#  ('UNION-AVE', 25),
#  ('SPRUCE-ST', 25),
#  ('CAMP', 25),
#  ('WEST-ST', 25),
#  ('VETERANS', 25),
#  ('FOX', 25),
#  ('13TH-ST', 25),
#  ('BIG', 25),
#  ('MILLS', 25),
#  ('P', 25),
#  ('FORD', 25),
#  ('36TH-ST', 25),
#  ('APT-4', 25),
#  ('CENTRE', 25),
#  ('VERNON', 25),
#  ('MONTGOMERY', 25),
#  ('SANTA-MONICA', 25),
#  ('MILLER', 25),
#  ('PENNSYLVANIA-AVE', 25),
#  ('BEAR', 25),
#  ('STE-116', 25),
#  ('BAKER', 25),
#  ('PRAIRIE', 25),
#  ('TRLR', 25),
#  ('SENECA', 24),
#  ('W-BROADWAY', 24),
#  ('CARSON', 24),
#  ('BIRCH', 24),
#  ('NORTH-ST', 24),
#  ('GALLERIA', 24),
#  ('W-3RD', 24),
#  ('53RD', 24),
#  ('WINDSOR', 24),
#  ('SCHOOL-RD', 24),
#  ('30TH', 24),
#  ('HOLLY', 24),
#  ('COURT-ST', 24),
#  ('RAILROAD-AVE', 24),
#  ('HALL', 24),
#  ('BUSINESS', 24),
#  ('GREAT', 24),
#  ('35TH', 24),
#  ('MONICA-BLVD', 24),
#  ('TELEGRAPH-RD', 24),
#  ('OLYMPIC-BLVD', 24),
#  ('OCEAN-AVE', 24),
#  ('VALLEY-VIEW', 24),
#  ('BEACH-RD', 24),
#  ('LOS-ANGELES', 24),
#  ('ANGELES', 24),
#  ('15TH-ST', 24),
#  ('MILWAUKEE', 24),
#  ('ALAMEDA', 24),
#  ('RD-E', 24),
#  ('MESA-BLVD', 24),
#  ('QUAIL', 24),
#  ('BROADWAY-AVE', 24),
#  ('HUNTINGTON', 23),
#  ('MASSACHUSETTS-AVE', 23),
#  ('PABLO', 23),
#  ('LAWRENCE', 23),
#  ('EMERALD', 23),
#  ('MARYLAND', 23),
#  ('N-2ND', 23),
#  ('KINGS-HWY', 23),
#  ('FLORENCE', 23),
#  ('25TH-ST', 23),
#  ('JAMES', 23),
#  ('WESTHEIMER', 23),
#  ('BAY-RD', 23),
#  ('TOWNE', 23),
#  ('POINT-RD', 23),
#  ('R', 23),
#  ('CLEVELAND', 23),
#  ('MERRICK', 23),
#  ('W-OLYMPIC', 23),
#  ('SHAW-AVE', 23),
#  ('EAST-AVE', 23),
#  ('OXFORD', 23),
#  ('JONES', 23),
#  ('TAYLOR', 23),
#  ('BREA', 23),
#  ('PIKE-STE', 23),
#  ('GARDEN-GROVE', 23),
#  ('MAPLE-ST', 23),
#  ('13TH-AVE', 23),
#  ('UNIVERSITY-BLVD', 23),
#  ('AUBURN', 23),
#  ('VIEW-RD', 23),
#  ('N-1ST', 23),
#  ('STREET-RD', 23),
#  ('IMPERIAL-HWY', 23),
#  ('VISTA-DR', 23),
#  ('MAR', 23),
#  ('O', 23),
#  ('MARTIN-LUTHER', 23),
#  ('LUTHER-KING', 23),
#  ('JR', 23),
#  ('NORTHERN', 22),
#  ('NORTHWEST-HWY', 22),
#  ('DELAWARE', 22),
#  ('THOMPSON', 22),
#  ('CAMPBELL-AVE', 22),
#  ('STE-160', 22),
#  ('28TH-ST', 22),
#  ('SUMMER', 22),
#  ('HOLLOW-RD', 22),
#  ('ROCK-RD', 22),
#  ('STATE-ROAD', 22),
#  ('UNIT-1', 22),
#  ('HOUSTON', 22),
#  ('DIAMOND', 22),
#  ('HOUSE', 22),
#  ('BLOSSOM', 22),
#  ('EVERGREEN', 22),
#  ('MONTEREY', 22),
#  ('PLEASANT-ST', 22),
#  ('LINCOLN-ST', 22),
#  ('GULF', 22),
#  ('LINDA', 22),
#  ('LAKEWOOD', 22),
#  ('RIO', 22),
#  ('CHICAGO', 22),
#  ('HOPE', 22),
#  ('H-ST', 22),
#  ('BLVD-NE', 22),
#  ('MILWAUKEE-AVE', 22),
#  ('E-6TH', 22),
#  ('COLORADO-BLVD', 22),
#  ('LINDEN', 22),
#  ('W-PICO', 22),
#  ('COLUMBUS', 22),
#  ('BLVD-N', 21),
#  ('PRINCETON', 21),
#  ('E-3RD', 21),
#  ('37TH', 21),
#  ('RT', 21),
#  ('HIDDEN', 21),
#  ('TERRACE', 21),
#  ('SAN-PABLO', 21),
#  ('CEDAR-ST', 21),
#  ('24TH-ST', 21),
#  ('N-HIGHWAY', 21),
#  ('MACARTHUR-BLVD', 21),
#  ('ADAMS-ST', 21),
#  ('CLUB-DR', 21),
#  ('ELK', 21),
#  ('LINCOLN-BLVD', 21),
#  ('ROOSEVELT-AVE', 21),
#  ('STE-9', 21),
#  ('19TH-ST', 21),
#  ('MANCHESTER', 21),
#  ('WESTHEIMER-RD', 21),
#  ('GEORGIA', 21),
#  ('LANCASTER-AVE', 21),
#  ('VERMONT', 21),
#  ('CRYSTAL', 21),
#  ('HUDSON', 21),
#  ('ARLINGTON', 21),
#  ('GARFIELD', 21),
#  ('9TH-AVE', 21),
#  ('STATION', 21),
#  ('W-BROAD', 21),
#  ('PLAZA-DR', 21),
#  ('DR-N', 21),
#  ('ARTHUR', 21),
#  ('BUFFALO', 21),
#  ('CENTER-RD', 21),
#  ('WHITTIER', 21),
#  ('LEXINGTON-AVE', 21),
#  ('S-HIGHWAY', 21),
#  ('FAIRFAX', 21),
#  ('N-3RD', 21),
#  ('GREENWOOD', 21),
#  ('RUN-RD', 21),
#  ('ROSECRANS', 21),
#  ('STE-203', 21),
#  ('PARKWAY', 21),
#  ('22ND', 21),
#  ('N-BROAD', 20),
#  ('POND-RD', 20),
#  ('BALDWIN', 20),
#  ('S-LA', 20),
#  ('STE-500', 20),
#  ('41ST', 20),
#  ('NECK', 20),
#  ('VICTORIA', 20),
#  ('WISCONSIN', 20),
#  ('GENESEE', 20),
#  ('CLARK-ST', 20),
#  ('DECATUR', 20),
#  ('HIGHWAY-1', 20),
#  ('MYRTLE', 20),
#  ('SPRINGFIELD', 20),
#  ('SYCAMORE', 20),
#  ('BEAVER', 20),
#  ('BELL-RD', 20),
#  ('WALK', 20),
#  ('CLIFF', 20),
#  ('HORSE-PIKE', 20),
#  ('PLACE', 20),
#  ('#-2', 20),
#  ('LANE', 20),
#  ('JERICHO', 20),
#  ('JERICHO-TPKE', 20),
#  ('KENNEDY', 20),
#  ('EUCLID-AVE', 20),
#  ('LAS-VEGAS', 20),
#  ('VEGAS', 20),
#  ('PRESTON-RD', 20),
#  ('ROUTE-9', 20),
#  ('AVE-FL', 20),
#  ('21ST-ST', 20),
#  ('SUNRISE-HWY', 20),
#  ('CHESTER', 20),
#  ('STE-11', 20),
#  ('23RD-ST', 20),
#  ('GLENDALE', 20),
#  ('WESTWOOD', 20),
#  ('MONROE-ST', 20),
#  ('WELLS', 20),
#  ('TOWER', 20),
#  ('FAIR-OAKS', 20),
#  ('8TH-AVE', 20),
#  ('PROVIDENCE', 20),
#  ('RUSSELL', 20),
#  ('SUNSET-DR', 20),
#  ('BROOKHURST', 20),
#  ('BROOKHURST-ST', 20),
#  ('PARK-LN', 20),
#  ('AUSTIN', 20),
#  ('APT-C', 20),
#  ('MCKINLEY', 19),
#  ('KENT', 19),
#  ('OAKLAND', 19),
#  ('HAWTHORNE-BLVD', 19),
#  ('HEMPSTEAD', 19),
#  ('MELROSE', 19),
#  ('WOODWARD', 19),
#  ('LAMAR', 19),
#  ('NECK-RD', 19),
#  ('NELSON', 19),
#  ('CT-APT', 19),
#  ('MERIDIAN', 19),
#  ('PULASKI', 19),
#  ('FOLSOM', 19),
#  ('ASH', 19),
#  ('31ST', 19),
#  ('IVY', 19),
#  ('E-2ND', 19),
#  ('CREEK-PKWY', 19),
#  ('CONGRESS-ST', 19),
#  ('HORIZON', 19),
#  ('FREMONT', 19),
#  ('ANN', 19),
#  ('RANDOLPH', 19),
#  ('48TH', 19),
#  ('HIGHWAY-111', 19),
#  ('RDG', 19),
#  ('ARROW', 19),
#  ('BEND-DR', 19),
#  ('COLONIAL', 19),
#  ('LONE', 19),
#  ('N-WASHINGTON', 19),
#  ('27TH', 19),
#  ('RIVER-DR', 19),
#  ('EASTON', 19),
#  ('20TH-ST', 19),
#  ('PEACHTREE-RD', 19),
#  ('HENRY', 19),
#  ('VEGAS-BLVD', 19),
#  ('U', 19),
#  ('SHERMAN-WAY', 19),
#  ('BEECH', 19),
#  ('GROVE-AVE', 19),
#  ('CREEK-BLVD', 19),
#  ('SCOTTSDALE', 19),
#  ('LAKESHORE', 19),
#  ('COOPER', 19),
#  ('RD-S', 19),
#  ('SAN-PEDRO', 19),
#  ('PEDRO', 19),
#  ('34TH', 19),
#  ('CASTLE', 19),
#  ('HILLTOP', 19),
#  ('DEL-MAR', 19),
#  ('FRANCIS', 19),
#  ('KING-JR', 19),
#  ('ROSECRANS-AVE', 19),
#  ('W-4TH', 19),
#  ('SPRINGS-DR', 18),
#  ('CANYON-BLVD', 18),
#  ('MARSHALL', 18),
#  ('HOLLYWOOD-BLVD', 18),
#  ('CHERRY-ST', 18),
#  ('GILBERT', 18),
#  ('CANAL-ST', 18),
#  ('ESSEX-ST', 18),
#  ('PABLO-AVE', 18),
#  ('W-7TH', 18),
#  ('PT', 18),
#  ('HIGHWAY-46', 18),
#  ('HILLSIDE-AVE', 18),
#  ('MANHATTAN', 18),
#  ('S-PARK', 18),
#  ('CARROLL', 18),
#  ('RICHMOND-AVE', 18),
#  ('BLOOMFIELD', 18),
#  ('NC', 18),
#  ('W-PARK', 18),
#  ('W-VALLEY', 18),
#  ('HIGHWAY-17', 18),
#  ('STE-600', 18),
#  ('LOWER', 18),
#  ('SHORE-DR', 18),
#  ('WHITNEY', 18),
#  ('SHADY', 18),
#  ('CAMBRIDGE', 18),
#  ('BRANCH-RD', 18),
#  ('HARBOR-BLVD', 18),
#  ('MIDWAY', 18),
#  ('PAUL', 18),
#  ('SANDY', 18),
#  ('PINES', 18),
#  ('HILLCREST', 18),
#  ('ERIE', 18),
#  ('GIRARD', 18),
#  ('SUNSET-RD', 18),
#  ('BALBOA', 18),
#  ('STOCKTON', 18),
#  ('FORD-RD', 18),
#  ('BRIGHTON', 18),
#  ('FAIRVIEW', 18),
#  ('VAN-DYKE', 18),
#  ('DYKE', 18),
#  ('GOLF', 18),
#  ('WARNER', 18),
#  ('KANSAS', 18),
#  ('N-7TH', 18),
#  ('DIXIE-HWY', 18),
#  ('22ND-ST', 18),
#  ('CONCORD', 17),
#  ('NORTHERN-BLVD', 17),
#  ('ANDERSON', 17),
#  ('STATE-RD', 17),
#  ('RUN-DR', 17),
#  ...]

# %%
df_addresses['NEW ADDRESS'].value_counts()
# Out:
# [['POB0', 'ALPHA'], ['POB2', 'ALPHA'], ['DIGIT']]                                                2059
# ("", [['DIGIT'], ['ALPHA'], ['WAY'], ['DIR']]),                                                   306
# ("", [['DIGIT'], ['ALPHA'], ['WAY'], ['LETTER', 'DIR']]),                                         233
# ("", [['DIGIT'], ['LETTER', 'DIR'], ['NTH', 'NUMSTR'], ['WAY', 'PRE'], ['APT'], ['DIGIT']]),      127
# ("", [['DIGIT'], ['ALPHA'], ['ALPHA'], ['WAY'], ['APT'], ['LETTER']]),                            110
# ("", [['DIGIT'], ['DIGIT'], ['ALPHA'], ['WAY']]),                                                  86
# ("", [['DIGIT'], ['ALPHA'], ['WAY', 'PRE'], ['DIR']]),                                             74
# ("", [['DIGIT'], ['ALPHA'], ['ALPHA'], ['ALPHA']]),                                                67
# ("", [['DIGIT'], ['ALPHA'], ['WAY'], ['ALPHA']]),                                                  56
# ("", [['DIGIT'], ['ALPHA'], ['WAY'], ['DIR'], ['APT'], ['DIGIT']]),                                51
# ("", [['DIGIT'], ['ALPHA'], ['WAY', 'PRE'], ['LETTER', 'DIR']]),                                   51
# ("", [['DIGIT'], ['DIGIT'], ['ALPHA'], ['WAY', 'PRE']]),                                           49
# ("", [['DIGIT'], ['ALPHA'], ['ALPHA'], ['DIGIT']]),                                                43
# ("", [['DIGIT'], ['ALPHA'], ['WAY'], ['APT'], ['DIGIT'], ['DIGIT']]),                              41
# ("", [['DIGIT'], ['ALPHA'], ['ALPHA'], ['APT'], ['DIGIT']]),                                       39
# ("", [['DIGIT'], ['LETTER', 'DIR'], ['ALPHA'], ['ALPHA']]),                                        39
# ("", [['DIGIT'], ['LETTER', 'DIR'], ['NTH', 'NUMSTR'], ['WAY', 'PRE'], ['APT'], ['LETTER']]),      37
# ("", [['DIGIT'], ['ALPHA'], ['ALPHA'], ['WAY'], ['POUND'], ['DIGIT']]),                            36
# ("", [['DIGIT'], ['ALPHA'], ['WAY'], ['WAY'], ['APT'], ['LETTER']]),                               36
# ("", [['DIGIT'], ['ALPHA'], ['WAY'], ['DIGIT'], ['APT'], ['DIGIT']]),                              31
# ("", [['DIGIT'], ['ALPHA'], ['WAY'], ['LETTER', 'DIR'], ['APT'], ['DIGIT']]),                      30
# ("", [['DIGIT'], ['LETTER'], ['WAY', 'PRE'], ['DIR']]),                                            30
# ("", [['DIGIT'], ['ALPHA'], ['ALPHA'], ['WAY'], ['APT'], ['ALNUM']]),                              27
# ("", [['DIGIT'], ['ALPHA'], ['APT'], ['DIGIT']]),                                                  27
# ("", [['DIGIT'], ['LETTER', 'DIR'], ['NTH', 'NUMSTR'], ['WAY', 'PRE'], ['LETTER', 'DIR']]),        26
# ("", [['DIGIT'], ['LETTER', 'DIR'], ['NTH', 'NUMSTR'], ['WAY'], ['APT'], ['DIGIT']]),              26
# ("", [['DIGIT'], ['ALPHA'], ['WAY'], ['POUND'], ['ALNUM']]),                                       25
# ("", [['DIGIT'], ['ALPHA'], ['WAY'], ['DIR'], ['APT'], ['LETTER']]),                               23
# ("", [['DIGIT'], ['LETTER', 'DIR'], ['ARTI'], ['ALPHA'], ['ALPHA']]),                              22
# ("", [['DIGIT'], ['DIGIT'], ['LETTER', 'DIR'], ['ALPHA'], ['WAY', 'PRE']]),                        21
#                                                                                                  ...
# 1810 MERRICK RD                                                                                     1
# 5026 PADDY TRCE                                                                                     1
# 832 PARKWAY                                                                                         1
# 1012 N WESTERN AVE                                                                                  1
# 108 E MARYLAND AVE                                                                                  1
# 7200 PAROTT DR                                                                                      1
# 6219 MID RIVERS MALL DR                                                                             1
# 525 W SOUTH BOULDER RD                                                                              1
# 53 MILTON AVE                                                                                       1
# 2420 CHICORY DR                                                                                     1
# 485 N 650 E                                                                                         1
# 23 ORLANDO ST                                                                                       1
# 1217 JEFFERSON DAVIS HWY                                                                            1
# 1228 HERMOSA AVE                                                                                    1
# 195 S WESTMONTE DR STE 1102                                                                         1
# 5333 ARVILLE ST STE 103                                                                             1
# 28 CRUZATTE AVE                                                                                     1
# 1086 GORHAM POND RD                                                                                 1
# 4566 MACK RD                                                                                        1
# 1553 S VIRGINIA ST                                                                                  1
# 5571 SKYWAY                                                                                         1
# 615 PARK PL                                                                                         1
# 1610 E CARSON ST                                                                                    1
# 640 E SUNSET DR N                                                                                   1
# 1224 HIGH ST                                                                                        1
# 238 DIXON LN                                                                                        1
# 19 MOUNT PLEASANT RD                                                                                1
# 11 W CROCKETT ST APT 404                                                                            1
# 2812 VAULX LN # B                                                                                   1
# 123 ELLIS RD STE B                                                                                  1
# Name: NEW ADDRESS, Length: 42429, dtype: int64

# %%
paths = sorted([pattern for st, pattern in tuples_training])
print(len(paths))

def convert_to_str_rep(path):
    rep = []
    for sub_lst in path:
        rep.append("-".join(sub_lst))
    return "|".join(rep)

arr_paths = []
for path in paths:
    if len(path) > 0:
        arr_paths.append(convert_to_str_rep(path))
    
#assert len(arr_paths) == len(list(set(arr_paths))), "should be unique"
print("UNIQUE PATHS: ", len(set(arr_paths)))
lst_paths = sorted(list(set(arr_paths)))
for path in set(arr_paths):
    print(path)
# Out:
# 76
# UNIQUE PATHS:  57
# DIGIT|ARTI|ALPHA|WAY|ADDRESS
# DIGIT|DIR|ALPHA|DIGIT|ADDRESS
# DIGIT|ALPHA|ALPHA|ALPHA|WAY|ADDRESS
# DIGIT|DIR|ALPHA|WAY|PERIOD|ADDRESS
# DIGIT|NTH|WAY|APT|ALNUM|ADDRESS
# DIGIT|NTH|WAY|DIR|ADDRESS
# DIGIT|DIR|ALPHA|WAY|DIGIT|ADDRESS
# DIGIT|DIR|ALPHA|WAY-PRE|APT|ALNUM|ADDRESS
# ALNUM|ALPHA|WAY|ADDRESS
# AL_1NUM|DIR|ALPHA|WAY|ADDRESS
# DIGIT|DIR|ALPHA|ADDRESS
# DIGIT|LETTER|ALPHA|WAY|ADDRESS
# DIGIT|ALPHA|WAY|APT|ALNUM|ADDRESS
# DIGIT|DIR|ALPHA|WAY|POUND|DIGIT|ADDRESS
# DIGIT|DIR|ALPHA|ALPHA|WAY|APT|DIGIT|ADDRESS
# DIGIT|NTH|WAY|ALPHA|DIGIT|ADDRESS
# DIGIT|DIR|ALPHA|WAY|APT|ALNUM|ADDRESS
# DIGIT|ALPHA|ALPHA|ADDRESS
# DIGIT|ALPHA|WAY|APT|DIGIT|ADDRESS
# DIGIT|ALPHA|ALPHA|WAY|APT|DIGIT|ADDRESS
# DIGIT|ALPHA|WAY|POUND|LETTER|ADDRESS
# DIGIT|DIR|ALPHA|WAY|APT|LETTER|ADDRESS
# DIGIT|NTH|WAY|ADDRESS
# DIGIT|DIR|ALPHA|WAY-PRE|POUND|DIGIT|ADDRESS
# AL_1NUM|NTH|WAY|ADDRESS
# DIGIT|PRE|ALPHA|WAY|ADDRESS
# DIGIT|ALPHA|DIGIT|ADDRESS
# DIGIT|ALPHA|WAY|DIGIT|DIR|ADDRESS
# DIGIT|ALPHA|WAY|ADDRESS
# DIGIT|DIR|WAY|DIGIT|ADDRESS
# DIGIT|ALPHA|WAY|DIGIT|ADDRESS
# DIGIT|DIR|DIGIT|ALPHA|WAY|ADDRESS
# DIGIT|NUMSTR|WAY|ADDRESS
# DIGIT|ALPHA|ADDRESS
# DIGIT|DIR|NUMSTR|WAY|ADDRESS
# DIGIT|ALPHA|ALPHA|WAY|DIR|ADDRESS
# AL_1NUM|ALPHA|ALPHA|WAY|ADDRESS
# DIGIT|ALPHA|WAY|APT|LETTER|ADDRESS
# DIGIT|ALPHA|ALPHA|WAY|ADDRESS
# DIGIT|ARTI|ALPHA|APT|LETTER|ADDRESS
# DIGIT|DIR|DIGIT|DIR|ADDRESS
# DIGIT|NTH|WAY|DIR|APT|DIGIT|ADDRESS
# DIGIT|WAY|DIGIT|APT|DIGIT|ADDRESS
# DIGIT|WAY|DIGIT|DIR|ADDRESS
# DIGIT|WAY|LETTER|ADDRESS
# DIGIT|ALPHA|WAY|ALNUM|ADDRESS
# DIGIT|DIR|WAY|LETTER|ADDRESS
# DIGIT|WAY|DIGIT|ADDRESS
# DIGIT|DIR|ALPHA|WAY|ADDRESS
# DIGIT|ALPHA|ALPHA|WAY|DIR|APT|DIGIT|ADDRESS
# DIGIT|ALPHA|WAY|POUND|DIGIT|ADDRESS
# DIGIT|ALPHA|DIR|ADDRESS
# DIGIT|WAY|DIGIT|APT|LETTER|ADDRESS
# DIGIT|ARTI|ALPHA|ALPHA|ADDRESS
# DIGIT|ALPHA|ARTI|ALPHA|ADDRESS
# DIGIT|DIR|WAY|DIGIT|APT|DIGIT|ADDRESS
# DIGIT|DIR|ALPHA|ALPHA|WAY|ADDRESS

# %%
lexicon = {
    'WAY': {
        'street': ['st', 'street'],
        'road':  ['rd', 'road'],
        'avenue': ['ave', 'avenue'],
        'court': ['ct']
        },
    'PRE': {
        'saint': ['st']
        },
    'ADDRESS': {
        ':adr'
        },
    'POBOX': {
        ':box'
    },
    'DIGIT': {
        'echo': []
    },
    'ALPHA': {
        'echo': []
    }
    
}

def get_normalized(word, _way, lexicon):
    for entry, lst_matches in lexicon[_way].items():
        if entry == 'echo':
            return word
        if word in lst_matches:
            return entry
    else:
        return None

print(get_normalized('st', 'PRE', lexicon))
print(get_normalized('st', 'WAY', lexicon))
# Out:
# saint
# street

# %%
# def encode_sentence(st):
#     return [encoder(word.lower()) for word in w(st)]

# def encode_nested_list(st):
#     return [[' '.join(encoder(word))] for word in w(st)]

# def train(seq, sts):
#     return seq.insert(encode_nested_list(sts)).get_next_values()



# def train_arr(seq, arr_w):
#     return seq.insert([[' '.join(encoder(word))] for word in arr_w]).get_next_values()

# def think(seq, sts):
#     return seq.insert(encode_nested_list(sts), is_learning=False).get_next_values()

# st = "100 n main st"
# print(train(seq, st))
# print(train_arr(seq, ["1217", "iris", "ct"]))
# print(train_with_provided_list(seq, [['DIGIT'],['ALPHA']]))
# print(train_with_provided_list(seq, [['DIGIT'], ['ALPHA'], ['WAY'], ['ADDRESS']]))
# print(encode_from_word_list(['123','st','james','st']))
